# %%
from ontology_algorithm import (
    draw_hierarchy_tree_from_ontology,
)
from integrative_worklow import (
    construct_topic_modeling_concept_hierarchy,
)
import re

# %% [markdown]
# # Preprocessing
#
# We will preprocess words from the theology reconsidered text using tf-idf and extract the top n words.

# %%
theology_reconsidered_path = "../data/theology_reconsidered.txt"

with open(theology_reconsidered_path, "r") as f:
    theology_reconsidered = f.read()


def split_into_chapters(input_filename, verbose=False):
    """Split the input file into chapters."""
    titles = []
    chapters = []
    # Open the input file and read its contents
    with open(input_filename, "r", encoding="utf-8") as input_file:
        contents = input_file.read()

    # Split the contents into chunks based on the separator criteria
    chunks = contents.split("\n\n\n\n")  # empty lines in the text

    ch_cnt = 0

    # Create an output file for each chunk
    for i, chunk in enumerate(chunks):
        # Skip empty chunks
        if not chunk.strip():
            continue

        # Extract the title and content from the chunk
        lines = chunk.strip().split("\n")
        title = lines[0]
        content = "\n".join(lines[1:])

        if verbose:
            print("processing CH" + str(ch_cnt) + ": " + title + "...")

        # Create the output file
        chapters.append(content)
        titles.append(title)

        ch_cnt += 1
    return titles, chapters


titles, chapters = split_into_chapters(theology_reconsidered_path)

chapters[0]

# Should I remove the word Figure?

# Remove \n from the chapters.
chapters = [chapter.replace("\n", "") for chapter in chapters]
# Remove \t from the chapters.
chapters = [chapter.replace("\t", " ") for chapter in chapters]


# import re

# Separate the chapters into sentences.
sentences_per_chapter_prep = [re.split("\.  ", chapter) for chapter in chapters]
sentences_per_chapter_prep = [
    [sentence + "." for sentence in chapter] for chapter in sentences_per_chapter_prep
]

sentences_per_chapter = []
for chapter_prep in sentences_per_chapter_prep:
    chapter = []
    for sentence in chapter_prep:
        chapter.extend(re.split("(?<!i.e|etc|e.g|iii)\. ", sentence))
    sentences_per_chapter.append(chapter)

# sentences_per_chapter[0]
for title_index, title in enumerate(titles):
    print(title_index, title)
# Out:
# 0 Introduction
# 1 Prologue: Mythos and Mysticism in Antiquity
# 2 A Brief History of the Mystical Arts: Beyond Yoga
# 3 Meditation as a Mystical Art: A Bridge Through Time
# 4 Overarching Themes: The Laurasian Hypothesis and a New Metaphysics
# 5 Setting the Stage: A Brief of History of Modern Man
# 6 Part I: On Creation Mythos (Cosmogony)
# 7 From Language to Writing: The Dawn of History
# 8 The Ancient Hebrews: The Tanakh, Torah and Five Books of Moses
# 9 Ancient Egyptian Mythos: The Weighing of the Heart, Ra and Ma'at
# 10 The Enûma Eliš: Sumer- Babylonian Creation Mythos
# 11 Ancient Persian Theology: Zarathustra and the Avesta
# 12 Classic Hellenic Theogony: Chaos, Chronos and Eros
# 13 Orphic Theogony: Thanes and the Great Cosmic Egg
# 14 Vedic Cosmogony: Skepticism, Puruṣa and Hiraṇyagarbha
# 15 Ancient Chinese Theology: Shàngdì, Pángǔ, Tiān and the Dao
# 16 Roman Cosmogony: The Metamorphoses of Ovid
# 17 Eurasian Mythos: Establishing the Laurasian Hypothesis
# 18 Part II: On Ancient Philosophy (Logos)
# 19 From the Far East: The Translation Challenge
# 20 Ancient Chinese Theology: From Shàngdì to Tiān
# 21 The Metaphysics of the I Ching: The Alignment of Heaven, Man and Earth
# 22 Upanishadic Philosophy: Brahmavidyā and the Soul
# 23 Buddhist Philosophy: Impermanence, Suffering and the "No-Self"
# 24 Pythagoras: The Father of Hellenic Philosophy
# 25 The Legacy of Socrates: Skepticism, Knowledge and Reason
# 26 Plato and the Allegory of the Cave: Ideas, Being and Becoming
# 27 Early Chinese Philosophy: The Humanism of Confucius
# 28 The Lǎozǐ and Zhuangzi: Daoism and the Way of Virtue
# 29 Indo-European Theo-Philosophy: On the Soul
# 30 Logos from Mythos: The Heart of Eurasian Philosophy
# 31 Part III: On Religion and Science
# 32 The Indo-Europeans: The Grandparents of Philosophy
# 33 Hellenic Theo-Philosophy: From Mythos to Logos
# 34 Aristotle's Metaphysics: Causality and Theology in Antiquity
# 35 Stoicism: Naturalism, Corporealism and Logos
# 36 The Seeds of Christianity: The Hellenization of Judaism
# 37 Islamic Philosophy: Allāh as the Final Cause
# 38 The Age of Enlightenment: The Philosophy of Science
# 39 The Metaphysics of Morality: Kantian Cognitive Ontology
# 40 Albert Einstein: Spacetime and Relativity Theory
# 41 Quantum Mechanics: Wave-Particle Duality and Uncertainty
# 42 Schrödinger's Cat: The Death of Local Realism
# 43 Part IV: On Ontology and Mysticism
# 44 The View from the West: The History of Objective Realism
# 45 Interpretations of Quantum Theory: Physics Meets Philosophy
# 46 Modern Psychology: Freud Versus Jung
# 47 Subject-Object Metaphysics and Quality: A Reformulation of Logical Positivism
# 48 Chinese Philosophy: Back to the Beginning
# 49 Vedic Theology: Vedānta and Brahmavidyā
# 50 Mysticism and Freud: Never the Two Shall Meet
# 51 Swami Vivekananda and Yoga: 20th Century Vedānta
# 52 Part V: Metaphysics in the Quantum Era
# 53 Ontology in the Quantum Era: A Retrospective
# 54 The Law of Unintended Consequences and The Death of the Soul
# 55 Into the Mystic: The Great Epistemological Divide
# 56 An Ontological Retrospective: Another Look at Aristotle and Pirsig
# 57 Metaphysics of Awareness

# %%
# Remove chapters, titles and sentences if the title starts with "Part ".
title_indices_to_remove = [
    title_index for title_index, title in enumerate(titles) if title.startswith("Part ")
]

titles = [
    title
    for title_index, title in enumerate(titles)
    if title_index not in title_indices_to_remove
]
sentences_per_chapter = [
    chapter
    for chapter_index, chapter in enumerate(sentences_per_chapter)
    if chapter_index not in title_indices_to_remove
]
chapters = [
    chapter
    for chapter_index, chapter in enumerate(chapters)
    if chapter_index not in title_indices_to_remove
]

# %% [markdown]
# ## Contruct the ontology tree using the integrative workflow

# %%
(ontology_hierarchy, all_relations_to_verbs, chapter_titles) = construct_topic_modeling_concept_hierarchy(
    chapters=chapters,
    titles=titles,
    sentences_per_chapter=sentences_per_chapter,
    num_topics=8,
    chosen_cluster=7,
    hierarchy_depth=5,
    hierarchy_max_width=5,
    n_key_terms=10,
    manually_added_roots=["dàodé jīng"],
    verbose=True,
)
# Draw the ontology hierarchy.
draw_hierarchy_tree_from_ontology(
    ontological_hierarchy=ontology_hierarchy,
    relations_to_verbs=all_relations_to_verbs,
    title="Theology reconsidered topic modeling cluster "
    + str(7)
    + " with "
    + str(len(chapter_titles))
    + " chapters",
    topic_modelling_chapters=chapter_titles,
)
# Out:
# CLUSTER #1
# Cluster Chapters: [1, 6, 7, 8, 9, 10, 11, 12, 13, 15, 16, 28, 30]
# Key Features: ['ancient', 'tradition', 'creation', 'gods', 'mythos', 'also', 'well', 'one', 'greek', 'philosophical']
# CLUSTER #2
# Cluster Chapters: [43, 51]
# Key Features: ['quality', 'pirsig', 'static', 'metaphysics', 'dynamic', 'experience', 'reality', 'subject object', 'metaphysics quality', 'static quality']
# CLUSTER #3
# Cluster Chapters: [20, 21, 23, 24, 27, 45]
# Key Features: ['knowledge', 'plato', 'brahman', 'socrates', 'suffering', 'philosophical', 'soul', 'vedānta', 'one', 'philosophy']
# CLUSTER #4
# Cluster Chapters: [0, 2, 3, 4, 5, 22, 29, 31, 46, 47]
# Key Features: ['philosophical', 'yoga', 'ramakrishna', 'ancient', 'well', 'theo', 'philosophy', 'work', 'theo philosophical', 'also']
# CLUSTER #5
# Cluster Chapters: [37, 38, 39, 40, 41, 48]
# Key Features: ['quantum', 'mechanics', 'theory', 'reality', 'relativity', 'quantum theory', 'einstein', 'quantum mechanics', 'subatomic', 'physics']
# CLUSTER #6
# Cluster Chapters: [36, 42, 49, 50, 52]
# Key Features: ['kant', 'intellectual', 'awareness', 'knowledge', 'epistemological', 'freud', 'reality', 'ontological', 'philosophical', 'metaphysics']
# CLUSTER #7
# Cluster Chapters: [14, 17, 18, 19, 25, 26, 44]
# Key Features: ['chinese', 'heaven', 'ancient', 'dynasty', 'one', 'confucius', 'ancient chinese', 'philosophical', 'dao', 'confucian']
# CLUSTER #8
# Cluster Chapters: [32, 33, 34, 35]
# Key Features: ['stoic', 'gnostic', 'god', 'christian', 'jesus', 'arabic', 'philosophical', 'jewish', 'philosophy', 'tradition']
#
#  Chosen chapters  [14, 17, 18, 19, 25, 26, 44]
# Removing the following terms:  []
# Removing  one  from current_level_words, it will be a child of  heaven
# Removing  heaven  from current_level_words, it will be a child of  dao
#
#  Current level:  0
# All children:  ['which', 'direct ancient ancestors', 'that', 'order', 'english', 'this', 'history', 'one', 'which', 'establishment', 'civilization', 'which', 'bygone age', 'justice', 'distinct philosophical system', 'trigrams', 'what', 'place', 'universal world order', 'ethical moral foundations', 'state', 'lu', 'eastern china', 'fact', 'class', 'priests', 'profound influence', 'many', 'lǎozǐ', 'one', 'things', 'classical chinese', 'what', 'things', 'myriad', 'different aspects', 'pattern', 'heaven', 'laws', 'more', 'individual spiritual focus', 'similar process', 'sifting process', 'lasting philosophical systems', 'daoism', 'example']
# Children to remove due to tf_idf_pre_filtering:  ['which', 'that', 'this', 'which', 'which', 'what', 'what', 'more']
# Children to remove due to used words:  []
# Current level words:  ['things', 'civilization', 'myriad', 'establishment', 'similar process', 'one', 'order', 'history', 'example', 'trigrams', 'state', 'many', 'fact', 'class', 'justice', 'heaven', 'one', 'things', 'laws', 'pattern', 'lǎozǐ', 'english', 'classical chinese', 'individual spiritual focus']
#
#  Current level:  1
# All children:  ['which', 'which', 'chaos', 'egg', 'years', 'two', 'them', 'obscurity', 'taiyi",in', 'spiritual', 'numinous', 'west', 'sands', 'time', 'beginning', 'eternal past', 'what', 'last year', 'tyrant', 'which', 'vast regional territories', 'various peoples', 'play', 'given sentence', 'passage', 'given context', 'references', 'terms', 'order', 'those', 'guiding principle', 'standard bearer', 'ethics', 'governance', 'form', 'it', 'present force', 'nature', 'one', 'what', 'righteousness', 'abominates', 'unrighteousness', 'men', 'reason', 'sun', 'moon', 'seasons', 'snow', 'frost', 'hills', 'rivers', 'ravines', 'many things', 'sky', 'heaven god', 'chinese pantheistic traditions', 'other words', 'divination purposes', 'one', 'definitive classes', 'one', 'turns', 'which', 'good ill fortune', 'sequence', 'world arrangement', 'south', 'directional based view', 'top', 'diagram', 'basic axis', 'interactive balancing forces', 'group', 'pairings', 'arrangement', 'world', 'man', 'disharmony', 'which', 'ritual', 'lǐ', 'them', 'tone', 'narrative', 'analects', 'weathered wise grandfather', 'ancient scripture', 'influence', 'state officials', 'conclusion', 'religiousness', 'confucianism', 'dao', 'what', 'symbol', 'us', 'which', 'peaceful harmonious life', 'turn', 'peaceful harmonious society', 'it', 'admirable way', 'complete distinctive constitutions', 'historic shamanistic characteristics', 'chinese system', 'direct representation', 'forms', 'fact']
# Children to remove due to tf_idf_pre_filtering:  ['which', 'which', 'them', 'taiyi",in', 'beginning', 'what', 'which', 'play', 'given sentence', 'given context', 'those', 'guiding principle', 'form', 'it', 'what', 'righteousness', 'abominates', 'snow', 'other words', 'which', 'directional based view', 'interactive balancing forces', 'which', 'them', 'what', 'us', 'which', 'it', 'complete distinctive constitutions', 'historic shamanistic characteristics']
# Children to remove due to used words:  ['order', 'one', 'one', 'one', 'dao', 'fact']
# Current level words:  ['two', 'unrighteousness', 'nature', 'years', 'ethics', 'moon', 'west', 'forms', 'ritual', 'peaceful harmonious life', 'world', 'man', 'sequence', 'good ill fortune', 'turns', 'definitive classes', 'obscurity', 'eternal past', 'passage', 'arrangement', 'time', 'disharmony', 'sands', 'symbol']
#
#  Current level:  2
# All children:  ['three', 'waters', 'floods', 'which', 'records', 'which', 'divine figures', 'what', 'philosophical tradition', 'milieu', 'anthropomorphic aspect', 'tiān shàngdì', 'it', 'righteousness', 'notion', 'heaven', 'chinese theo philosophy', 'great task', 'which', 'linear process', 'prototypical western outlook', 'belief system', 'circular octagonal form', 'arrangement', 'arrangement', 'west', 'east', 'next passage', 'shuogua', 'cardinal points', 'movement', 'level', 'spectrum', 'world views', 'they', 'heaven', 'earth', 'it', 'enough', 'which', 'balance', 'harmony']
# Children to remove due to tf_idf_pre_filtering:  ['which', 'which', 'what', 'it', 'righteousness', 'chinese theo philosophy', 'which', 'circular octagonal form', 'level', 'they', 'it', 'enough', 'which']
# Children to remove due to used words:  ['heaven', 'arrangement', 'arrangement', 'west', 'heaven']
# Current level words:  ['harmony', 'notion', 'balance', 'earth', 'three', 'world views', 'spectrum', 'divine figures', 'anthropomorphic aspect', 'tiān shàngdì', 'movement', 'shuogua', 'cardinal points', 'next passage', 'records', 'belief system', 'linear process', 'prototypical western outlook', 'philosophical tradition', 'milieu', 'floods', 'waters', 'east', 'great task']
#
#  Current level:  3
# All children:  ['lowest depth', 'things', 'rest', 'this', 'birth', 'cosmic world order', 'divination process', 'definitive laws', 'bottom', 'diagram', 'course', 'natural psychic manifestations', 'levels', 'numerological', 'myriad creatures', 'many phases', 'development', 'attainment', 'set', 'achievement', 'certain state']
# Children to remove due to tf_idf_pre_filtering:  ['rest', 'this', 'set']
# Children to remove due to used words:  ['things']
# Current level words:  ['course', 'bottom', 'diagram', 'lowest depth', 'divination process', 'achievement', 'cosmic world order', 'attainment', 'certain state', 'numerological', 'levels', 'natural psychic manifestations', 'definitive laws', 'birth', 'myriad creatures', 'development', 'many phases']
#
#  Current level:  4
# All children:  ['ancient chinese forms', 'backs', 'yīn', 'arms', 'yáng', 'way', 'place', 'qualities', 'dao']
# Children to remove due to tf_idf_pre_filtering:  []
# Children to remove due to used words:  ['dao']
# Current level words:  ['way', 'qualities', 'ancient chinese forms', 'place', 'yīn', 'yáng', 'backs', 'arms']
