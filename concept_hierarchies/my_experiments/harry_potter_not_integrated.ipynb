# %%
from preprocessing import (
    get_word_types_with_tf_idf
)
from extract_relations import (
    get_directed_relations,
    order_directed_relations,
)
from ontology_algorithm import (
    construct_ontology_hierarchy,
    draw_hierarchy_tree_from_ontology,
)
from topic_modeling import kmeans_tfidf_clustering
import pandas as pd

# %%
harry_potter_path = '../data/harry_potter_books.csv'

df = pd.read_csv(harry_potter_path)
# Philosophers stone
philosophers_stone_df = df.query(f'book == "Book 1: Philosopher\'s Stone"')

# Check to make sure dataframe info looks correct 
print(philosophers_stone_df["book"].unique())
philosophers_stone_df.head(20)
# Out:
# ["Book 1: Philosopher's Stone"]
#                                                  text  \
# 0   THE BOY WHO LIVED  Mr. and Mrs. Dursley, of nu...
# 1   four, Privet Drive, were proud to say that the...
# 2   thank you very much. They were the last people...
# 3   be involved in anything strange or mysterious,...
# 4   with such nonsense.  Mr. Dursley was the direc...
# 5   called Grunnings, which made drills. He was a ...
# 6   hardly any neck, although he did have a very l...
# 7   Dursley was thin and blonde and had nearly twi...
# 8   of neck, which came in very useful as she spen...
# 9   of her time craning over garden fences, spying...
# 10  Dursleys had a small son called Dudley and in ...
# 11  was no finer boy anywhere.  The Dursleys had e...
# 12  but they also had a secret, and their greatest...
# 13  somebody would discover it. They didn't think ...
# 14  anyone found out about the Potters. Mrs. Potte...
# 15  but they hadn't met for several years; in fact...
# 16  she didn't have a sister, because her sister a...
# 17  were as unDursleyish as it was possible to be....
# 18  to think what the neighbors would say if the P...
# 19  the street. The Dursleys knew that the Potters...
#
#                            book chapter
# 0   Book 1: Philosopher's Stone  chap-1
# 1   Book 1: Philosopher's Stone  chap-1
# 2   Book 1: Philosopher's Stone  chap-1
# 3   Book 1: Philosopher's Stone  chap-1
# 4   Book 1: Philosopher's Stone  chap-1
# 5   Book 1: Philosopher's Stone  chap-1
# 6   Book 1: Philosopher's Stone  chap-1
# 7   Book 1: Philosopher's Stone  chap-1
# 8   Book 1: Philosopher's Stone  chap-1
# 9   Book 1: Philosopher's Stone  chap-1
# 10  Book 1: Philosopher's Stone  chap-1
# 11  Book 1: Philosopher's Stone  chap-1
# 12  Book 1: Philosopher's Stone  chap-1
# 13  Book 1: Philosopher's Stone  chap-1
# 14  Book 1: Philosopher's Stone  chap-1
# 15  Book 1: Philosopher's Stone  chap-1
# 16  Book 1: Philosopher's Stone  chap-1
# 17  Book 1: Philosopher's Stone  chap-1
# 18  Book 1: Philosopher's Stone  chap-1
# 19  Book 1: Philosopher's Stone  chap-1

# %%
# Chapter titles for Philosopher's Stone book
titles = [
    'The Boy Who Lived',
    'The Vanishing Glass',
    'The Letters From No One',
    'The Keeper of the Keys',
    'Diagon Alley',
    'The Journey from Platform Nine and Three-Quarters',
    'The Sorting Hat',
    'The Potions Master',
    'The Midnight Duel',
    'Hallowe\'en',
    'Quidditch',
    'The Mirror of Erised',
    'Nicolas Flamel',
    'Norbert the Norwegian Ridgeback',
    'The Forbidden Forest',
    'Through the Trapdoor',
    'The Man with Two Faces'
    ]

chapters = []
sentences_per_chapter = []
chapter_text = ''
chapter_df = df
for chapter in philosophers_stone_df["chapter"].unique().tolist():
    chapter_df = philosophers_stone_df.query(f"chapter == '{chapter}'")
    chapter_text = ''
    temp = []
    for text in chapter_df["text"].values.tolist():
        chapter_text += text + ' '
        temp.append(text)
    chapters.append(chapter_text)
    sentences_per_chapter.append(temp)

# %%
num_topics = 4
clusters, key_terms_per_cluster = kmeans_tfidf_clustering(chapters = chapters, num_topics = num_topics)
clusters
# Out:
# CLUSTER #1
# Cluster Chapters: [4, 7, 13, 14]
# Key Features: ['hagrid', 'hermione', 'ron', 'yeh', 'said hagrid', 'norbert', 'snape', 'ter', 'ronan', 'malfoy', 'fang', 'firenze', 'dragon', 'professor', 'unicorn', 'ollivander', 'said harry', 'yer', 'bane', 'mr ollivander', 'neville', 'potter', 'wand', 'forest', 'well', 'quirrell', 'filch', 'mr', 'harry hermione', 'fer', 'charlie', 'cauldron', 'bit', 'anythin', 'griphook', 'tell', 'gringotts', 'go', 'magic', 'class', 'two', 'path', 'told', 'stone', 'keep', 'harry ron', 'night', 'dragons', 'centaur', 'dark']
# CLUSTER #2
# Cluster Chapters: [1, 2, 3]
# Key Features: ['dudley', 'vernon', 'uncle vernon', 'uncle', 'aunt', 'aunt petunia', 'petunia', 'yeh', 'ter', 'hagrid', 'piers', 'cupboard', 'snake', 'kitchen', 'dursleys', 'car', 'letter', 'letters', 'dudleys', 'giant', 'dursley', 'glass', 'go', 'school', 'came', 'house', 'crash', 'never', 'yer', 'sofa', 'television', 'knew', 'room', 'dad', 'smelting stick', 'smelting', 'hogwarts', 'mother', 'said uncle', 'wizard', 'zoo', 'said harry', 'anything', 'world', 'old', 'dudley piers', 'boy', 'figg', 'mrs figg', 'computer']
# CLUSTER #3
# Cluster Chapters: [5, 6, 8, 9, 10, 11, 12, 15, 16]
# Key Features: ['ron', 'hermione', 'snape', 'neville', 'said ron', 'malfoy', 'professor', 'gryffindor', 'dumbledore', 'quirrell', 'wood', 'mirror', 'hagrid', 'said harry', 'stone', 'go', 'percy', 'hat', 'troll', 'never', 'us', 'mcgonagall', 'professor mcgonagall', 'broom', 'two', 'weasley', 'slytherin', 'quidditch', 'well', 'room', 'told', 'quaffle', 'team', 'toward', 'harry ron', 'flamel', 'three', 'peeves', 'flint', 'boy', 'ron hermione', 'hogwarts', 'said hermione', 'last', 'broomstick', 'filch', 'cloak', 'fred', 'away', 'great']
# CLUSTER #4
# Cluster Chapters: [0]
# Key Features: ['dursley', 'mr dursley', 'mrs dursley', 'cat', 'dumbledore', 'mr', 'mrs', 'street', 'professor mcgonagall', 'professor', 'mcgonagall', 'potters', 'said dumbledore', 'son', 'drills', 'owls', 'privet drive', 'privet', 'hagrid', 'drive', 'shooting stars', 'man', 'name', 'dudley', 'motorcycle', 'shooting', 'lemon', 'blankets', 'yes', 'sister', 'cloak', 'boy', 'people cloaks', 'tabby', 'number', 'said professor', 'number four', 'saying', 'voldemort', 'potter', 'normal', 'dursleys', 'cloaks', 'celebrating', 'daylight', 'bundle', 'muggles', 'never', 'stars', 'road']
# {1: [4, 7, 13, 14], 2: [1, 2, 3], 3: [5, 6, 8, 9, 10, 11, 12, 15, 16], 4: [0]}

# %%
cluster = 2
cluster_chapters = clusters[cluster]
cluster_titles = [titles[i] for i in cluster_chapters]
key_terms = key_terms_per_cluster[cluster]

text_per_chapter = []
for idx in cluster_chapters:
    text_per_chapter.append(chapters[idx])
    
tf_idf_pre_filtering = get_word_types_with_tf_idf(
    text_per_chapter,
    "tf",
    skip_stopwords=True,
    include_verbs=False,
    include_determiners=False,
    include_pronouns=False,
    include_adverbs=False,
    include_numbers=True,
)

all_verses = []
for chapter_idx in cluster_chapters:
    all_verses.extend(sentences_per_chapter[chapter_idx])

top_n_words = tf_idf_pre_filtering.head(50)['word'].values

directed_relations, relations_to_verbs = get_directed_relations(
    top_n_words=top_n_words,
    all_verses=all_verses,
    only_compounds=True,
    verbose=True,
)

ordered_directed_relations = order_directed_relations(
    directed_relations=directed_relations,
    tf_idf_pre_filtering=tf_idf_pre_filtering,
    order_by="tf_idf",
    include_ordering_wrt_occurences=True,
    verbose=False,
)

ontology_hierarchy, words_with_parents = construct_ontology_hierarchy(
    ordered_directed_relations=ordered_directed_relations,
)

draw_hierarchy_tree_from_ontology(
    ontological_hierarchy=ontology_hierarchy,
    relations_to_verbs=relations_to_verbs
)
# Out:
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tf = pd.concat([tf, row_df], ignore_index=True)
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   idf = pd.concat([idf, row_df], ignore_index=True)
#  1  sentences in verse  0
# sentence:  THE VANISHING GLASS  Nearly ten years had passed since the Dursleys
# ents:  [VANISHING, Nearly ten years, Dursleys]
# subject:  GLASS
# Compounds:  ['VANISHING']
# object:  Dursleys
#
#  1  sentences in verse  1
# sentence:  had woken up to find their nephew on the front step, but
# ents:  []
#
#  2  sentences in verse  2
# sentence:  Privet Drive had hardly changed at all.
# ents:  []
# subject:  Drive
# Negative adverb:  hardly .
# Compounds:  ['Privet']
# sentence:  The sun rose on the
# ents:  []
# subject:  sun
# object:  the
#
#  1  sentences in verse  3
# sentence:  same tidy front gardens and lit up the brass number four on
# ents:  [four]
# subject:  gardens
# More than 2 compounds found for word:  gardens
# Compunds:  ['same', 'tidy', 'front']
# object:  number
# Compounds:  ['brass']
#
#  1  sentences in verse  4
# sentence:  the Dursleys' front door; it crept into their living room, which was
# ents:  [Dursleys]
# subject:  it
# object:  room
# Compounds:  ['living']
# subject:  which
#
#  1  sentences in verse  5
# sentence:  almost exactly the same as it had been on the night when
# ents:  [the night]
# subject:  it
# object:  night
#
#  2  sentences in verse  6
# sentence:  Mr. Dursley had seen that fateful news report about the owls.
# ents:  [Dursley]
# subject:  Dursley
# Compounds:  ['Mr.']
# object:  report
# Compounds:  ['fateful', 'news']
# object:  owls
# sentence:  Only
# ents:  []
#
#  1  sentences in verse  7
# sentence:  the photographs on the mantelpiece really showed how much time had passed.
# ents:  []
# subject:  photographs
# subject:  time
# Compounds:  ['much']
#
#  1  sentences in verse  8
# sentence:  Ten years ago, there had been lots of pictures of what looked
# ents:  [Ten years ago]
# subject:  what
#
#  1  sentences in verse  9
# sentence:  like a large pink beach ball wearing different-colored bonnets -- but Dudley
# ents:  [Dudley]
#
#  1  sentences in verse  10
# sentence:  Dursley was no longer a baby, and now the photographs showed a
# ents:  [Dursley]
# subject:  Dursley
# subject:  photographs
# object:  a
#
#  1  sentences in verse  11
# sentence:  large blond boy riding his first bicycle, on a carousel at the
# ents:  [first]
#
#  1  sentences in verse  12
# sentence:  fair, playing a computer game with his father, being hugged and kissed
# ents:  []
#
#  2  sentences in verse  13
# sentence:  by his mother.
# ents:  []
# sentence:  The room held no sign at all that another
# ents:  []
# subject:  room
# object:  sign
# Negative object determiner:  no .
# Reverting order of relation.
# object:  that
#
#  2  sentences in verse  14
# sentence:  boy lived in the house, too.
# ents:  []
# subject:  boy
# object:  house
# Adding relation: ' boy ' -> ' house '
# sentence:  Yet Harry Potter was still
# ents:  [Harry Potter]
# subject:  Potter
# Compounds:  ['Harry']
#
#  2  sentences in verse  15
# sentence:  there, asleep at the moment, but not for long.
# ents:  []
# sentence:  His Aunt Petunia
# ents:  []
#
#  1  sentences in verse  16
# sentence:  was awake and it was her shrill voice that made the first
# ents:  [first]
# subject:  it
# subject:  that
# object:  first
#
#  5  sentences in verse  17
# sentence:  noise of the day.
# ents:  [the day]
# sentence:  `Up!
# ents:  []
# sentence:  Get up!
# ents:  []
# sentence:  Now!`
# ents:  []
# sentence:  Harry woke
# ents:  []
# subject:  Harry
#
#  3  sentences in verse  18
# sentence:  with a start.
# ents:  []
# sentence:  His aunt rapped on the door again.
# ents:  []
# subject:  aunt
# object:  door
# Adding relation: ' aunt ' -> ' door '
# sentence:  `Up!`
# ents:  []
#
#  2  sentences in verse  19
# sentence:  she screeched.
# ents:  []
# subject:  she
# sentence:  Harry heard her walking toward the kitchen and then the
# ents:  [Harry]
# subject:  Harry
# subject:  her
# object:  kitchen
#
#  2  sentences in verse  20
# sentence:  sound of the frying pan being put on the stove.
# ents:  []
# subject:  sound
# object:  stove
# sentence:  He rolled
# ents:  []
# subject:  He
#
#  1  sentences in verse  21
# sentence:  onto his back and tried to remember the dream he had been
# ents:  []
# subject:  he
#
#  3  sentences in verse  22
# sentence:  having.
# ents:  []
# sentence:  It had been a good one.
# ents:  []
# subject:  It
# sentence:  There had been a flying
# ents:  []
#
#  2  sentences in verse  23
# sentence:  motorcycle in it.
# ents:  []
# sentence:  He had a funny feeling he'd had the same
# ents:  []
# subject:  He
# object:  feeling
# Compounds:  ['funny']
# subject:  he
# object:  same
#
#  3  sentences in verse  24
# sentence:  dream before.
# ents:  []
# sentence:  His aunt was back outside the door.
# ents:  []
# subject:  aunt
# sentence:  `Are
# ents:  []
#
#  3  sentences in verse  25
# sentence:  you up yet?` she demanded.
# ents:  []
# subject:  you
# subject:  she
# sentence:  `Nearly,` said Harry.
# ents:  [Harry]
# subject:  Harry
# sentence:  `Well, get
# ents:  []
#
#  2  sentences in verse  26
# sentence:  a move on, I want you to look after the bacon.
# ents:  []
# subject:  I
# subject:  you
# object:  bacon
# sentence:  And
# ents:  []
#
#  1  sentences in verse  27
# sentence:  don't you dare let it burn, I want everything perfect on Duddy's
# ents:  [Duddy]
# subject:  you
# subject:  it
# subject:  I
# object:  everything
# Compounds:  ['perfect']
#
#  3  sentences in verse  28
# sentence:  birthday.`
# ents:  []
# sentence:  Harry groaned.
# ents:  [Harry]
# subject:  Harry
# sentence:  `What did you say?` his aunt snapped
# ents:  []
# subject:  you
# object:  What
# subject:  aunt
#
#  2  sentences in verse  29
# sentence:  through the door.
# ents:  []
# sentence:  `Nothing, nothing...`  Dudley's birthday -- how could he
# ents:  [Dudley]
# subject:  he
#
#  2  sentences in verse  30
# sentence:  have forgotten?
# ents:  []
# sentence:  Harry got slowly out of bed and started looking for
# ents:  [Harry]
# subject:  Harry
# Using conjunct subject:  Harry
#
#  2  sentences in verse  31
# sentence:  socks.
# ents:  []
# sentence:  He found a pair under his bed and, after pulling a
# ents:  []
# subject:  He
# object:  pair
# object:  bed
#
#  2  sentences in verse  32
# sentence:  spider off one of them, put them on.
# ents:  [one]
# subject:  spider
# object:  them
# sentence:  Harry was used to
# ents:  [Harry]
# subject:  Harry
#
#  1  sentences in verse  33
# sentence:  spiders, because the cupboard under the stairs was full of them, and
# ents:  []
# subject:  cupboard
#
#  2  sentences in verse  34
# sentence:  that was where he slept.
# ents:  []
# subject:  that
# subject:  he
# sentence:  When he was dressed he went
# ents:  []
# subject:  he
# subject:  he
#
#  2  sentences in verse  35
# sentence:  down the hall into the kitchen.
# ents:  []
# sentence:  The table was almost hidden beneath
# ents:  []
# subject:  table
#
#  2  sentences in verse  36
# sentence:  all Dudley's birthday presents.
# ents:  [Dudley]
# sentence:  It looked as though Dudley had gotten the
# ents:  [Dudley]
# subject:  It
# subject:  Dudley
# object:  the
#
#  1  sentences in verse  37
# sentence:  new computer he wanted, not to mention the second television and the
# ents:  [second]
# subject:  he
#
#  2  sentences in verse  38
# sentence:  racing bike.
# ents:  []
# sentence:  Exactly why Dudley wanted a racing bike was a mystery
# ents:  [Dudley]
# subject:  Dudley
# subject:  bike
# Compounds:  ['racing']
#
#  2  sentences in verse  39
# sentence:  to Harry, as Dudley was very fat and hated exercise --
# ents:  [Harry, Dudley]
# subject:  Dudley
# sentence:  unless
# ents:  []
#
#  2  sentences in verse  40
# sentence:  of course it involved punching somebody.
# ents:  []
# subject:  it
# object:  course
# sentence:  Dudley's favorite punching bag was Harry,
# ents:  [Dudley, Harry]
# subject:  bag
# Compounds:  ['favorite', 'punching']
#
#  2  sentences in verse  41
# sentence:  but he couldn't often catch him.
# ents:  []
# subject:  he
# object:  him
# sentence:  Harry didn't look it, but he
# ents:  [Harry]
# subject:  Harry
# object:  it
#
#  2  sentences in verse  42
# sentence:  was very fast.
# ents:  []
# sentence:  Perhaps it had something to do with living
# ents:  []
# subject:  it
# object:  something
#
#  1  sentences in verse  43
# sentence:  in a dark cupboard, but Harry had always been small and skinny
# ents:  [Harry]
# subject:  Harry
# object:  cupboard
# Compounds:  ['dark']
#
#  2  sentences in verse  44
# sentence:  for his age.
# ents:  []
# sentence:  He looked even smaller and skinnier than he really
# ents:  []
# subject:  He
# object:  he
#
#  1  sentences in verse  45
# sentence:  was because all he had to wear were old clothes of Dudley's,
# ents:  [Dudley]
# subject:  he
# subject:  all
#
#  2  sentences in verse  46
# sentence:  and Dudley was about four times bigger than he was.
# ents:  [Dudley, about four]
# subject:  Dudley
# subject:  he
# sentence:  Harry had
# ents:  [Harry]
# subject:  Harry
#
#  2  sentences in verse  47
# sentence:  a thin face, knobbly knees, black hair, and bright green eyes.
# ents:  []
# sentence:  He
# ents:  []
#
#  1  sentences in verse  48
# sentence:  wore round glasses held together with a lot of Scotch tape because
# ents:  [Scotch]
#
#  2  sentences in verse  49
# sentence:  of all the times Dudley had punched him on the nose.
# ents:  [Dudley]
# subject:  Dudley
# object:  times
# object:  him
# object:  nose
# sentence:  The
# ents:  []
#
#  1  sentences in verse  50
# sentence:  only thing Harry liked about his own appearance was a very thin
# ents:  [Harry]
# subject:  Harry
# object:  appearance
# Compounds:  ['own']
# subject:  thing
#
#  1  sentences in verse  51
# sentence:  scar on his forehead that was shaped like a bolt of lightning.
# ents:  []
# subject:  that
# object:  bolt
# object:  lightning
#
#  1  sentences in verse  52
# sentence:  He had had it as long as he could remember, and the
# ents:  []
# subject:  He
# object:  it
# subject:  he
#
#  1  sentences in verse  53
# sentence:  first question he could ever remember asking his Aunt Petunia was how
# ents:  [first]
# subject:  he
# subject:  question
# Compounds:  ['first']
#
#  2  sentences in verse  54
# sentence:  he had gotten it.
# ents:  []
# subject:  he
# object:  it
# sentence:  `In the car crash when your parents
# ents:  []
#
#  2  sentences in verse  55
# sentence:  died,` she had said.
# ents:  []
# subject:  she
# sentence:  `And don't ask questions.`  Don't ask questions
# ents:  []
#
#  1  sentences in verse  56
# sentence:  -- that was the first rule for a quiet life with the
# ents:  [first]
# subject:  that
#
#  2  sentences in verse  57
# sentence:  Dursleys.
# ents:  []
# sentence:  Uncle Vernon entered the kitchen as Harry was turning over
# ents:  [Uncle Vernon, Harry]
# subject:  Vernon
# Compounds:  ['Uncle']
# object:  kitchen
# Adding relation: ' uncle vernon ' -> ' kitchen '
# subject:  Harry
#
#  2  sentences in verse  58
# sentence:  the bacon.
# ents:  []
# sentence:  `Comb your hair!` he barked, by way of a
# ents:  []
# subject:  he
# object:  way
# object:  a
#
#  2  sentences in verse  59
# sentence:  morning greeting.
# ents:  [morning]
# sentence:  About once a week, Uncle Vernon looked over the top
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# object:  top
#
#  2  sentences in verse  60
# sentence:  of his newspaper and shouted that Harry needed a haircut.
# ents:  [Harry]
# subject:  Harry
# object:  haircut
# sentence:  Harry must
# ents:  [Harry]
# subject:  Harry
#
#  1  sentences in verse  61
# sentence:  have had more haircuts than the rest of the boys in his
# ents:  []
#
#  1  sentences in verse  62
# sentence:  class put  together, but it made no difference, his hair simply
# ents:  []
# subject:  class
# object:  hair
# subject:  it
# object:  difference
# Negative object determiner:  no .
# Reverting order of relation.
#
#  2  sentences in verse  63
# sentence:  grew that way -- all over the place.
# ents:  []
# sentence:  Harry was frying
# ents:  [Harry]
# subject:  Harry
#
#  1  sentences in verse  64
# sentence:  eggs by the time Dudley arrived in the kitchen with his mother.
# ents:  [Dudley]
# subject:  Dudley
# object:  kitchen
# Adding relation: ' dudley ' -> ' kitchen '
# object:  mother
#
#  2  sentences in verse  65
# sentence:  Dudley looked a lot like Uncle Vernon.
# ents:  [Dudley, Uncle Vernon]
# subject:  Dudley
# object:  Vernon
# Compounds:  ['Uncle']
# Adding relation: ' dudley ' -> ' uncle vernon '
# sentence:  He had a large pink
# ents:  []
# subject:  He
# object:  pink
# Compounds:  ['large']
#
#  1  sentences in verse  66
# sentence:  face, not much neck, small, watery blue eyes, and thick blond hair
# ents:  []
#
#  2  sentences in verse  67
# sentence:  that lay smoothly on his thick, fat head.
# ents:  []
# subject:  that
# object:  head
# Compounds:  ['thick', 'fat']
# sentence:  Aunt Petunia often said
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
#
#  1  sentences in verse  68
# sentence:  that Dudley looked like a baby angel -- Harry often said that
# ents:  [Dudley, Harry]
# subject:  Dudley
# object:  angel
# Compounds:  ['baby']
# subject:  Harry
# object:  that
#
#  2  sentences in verse  69
# sentence:  Dudley looked like a pig in a wig.
# ents:  [Dudley]
# subject:  Dudley
# object:  pig
# object:  wig
# sentence:  Harry put the
# ents:  [Harry]
# subject:  Harry
# object:  the
#
#  1  sentences in verse  70
# sentence:  plates of egg and bacon on the table, which was difficult as
# ents:  []
# subject:  which
#
#  3  sentences in verse  71
# sentence:  there wasn't much room.
# ents:  []
# sentence:  Dudley, meanwhile, was counting his presents.
# ents:  [Dudley]
# subject:  Dudley
# object:  presents
# sentence:  His face
# ents:  []
#
#  2  sentences in verse  72
# sentence:  fell.
# ents:  []
# sentence:  `Thirty-six,` he said, looking up at his mother and father.
# ents:  [Thirty-six]
# subject:  he
#
#  2  sentences in verse  73
# sentence:  `That's two less than last year.`
# ents:  [two, last year]
# subject:  That
# sentence:  `Darling, you haven't counted Auntie
# ents:  []
# subject:  you
# object:  Auntie
#
#  1  sentences in verse  74
# sentence:  Marge's present, see, it's here under this big one from Mommy and
# ents:  [Marge, Mommy]
# subject:  present
# subject:  it
# object:  one
# Compounds:  ['big']
# object:  Mommy
#
#  2  sentences in verse  75
# sentence:  Daddy.`
# ents:  []
# sentence:  `All right, thirty-seven then,` said Dudley, going red in the
# ents:  [thirty-seven, Dudley]
# subject:  Dudley
#
#  2  sentences in verse  76
# sentence:  face.
# ents:  []
# sentence:  Harry, who could see a huge Dudley tantrum coming on, began
# ents:  [Harry, Dudley]
# subject:  who
# object:  tantrum
# Compounds:  ['huge', 'Dudley']
# subject:  Harry
#
#  1  sentences in verse  77
# sentence:  wolfing down his bacon as fast as possible in case Dudley turned
# ents:  [Dudley]
# subject:  Dudley
# object:  case
#
#  2  sentences in verse  78
# sentence:  the table over.
# ents:  []
# sentence:  Aunt Petunia obviously scented danger, too, because she
# ents:  []
#
#  1  sentences in verse  79
# sentence:  said quickly, `And we'll buy you another two presents while we're out
# ents:  [two]
# subject:  we
# dative:  you
# object:  presents
# subject:  we
#
#  4  sentences in verse  80
# sentence:  today.
# ents:  [today]
# sentence:  How's that, popkin?
# ents:  []
# subject:  that
# sentence:  Two more presents.
# ents:  [Two]
# sentence:  Is that all right''
# ents:  []
# subject:  that
#
#  3  sentences in verse  81
# sentence:  Dudley thought for a moment.
# ents:  [Dudley]
# subject:  Dudley
# object:  moment
# sentence:  It looked like hard work.
# ents:  []
# subject:  It
# object:  work
# Compounds:  ['hard']
# sentence:  Finally he
# ents:  []
#
#  1  sentences in verse  82
# sentence:  said slowly, `So I'll have thirty ... thirty...`  `Thirty-nine, sweetums,` said
# ents:  [thirty ... thirty, Thirty-nine]
# subject:  I
# object:  thirty
#
#  2  sentences in verse  83
# sentence:  Aunt Petunia.
# ents:  []
# sentence:  `Oh.` Dudley sat down heavily and grabbed the nearest
# ents:  [Dudley]
# subject:  Dudley
# Using conjunct subject:  Dudley
# object:  nearest
#
#  3  sentences in verse  84
# sentence:  parcel.
# ents:  []
# sentence:  `All right then.`  Uncle Vernon chuckled.
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# sentence:  `Little tyke wants his
# ents:  []
# subject:  tyke
# Compounds:  ['Little']
# object:  his
#
#  3  sentences in verse  85
# sentence:  money's worth, just like his father. '
# ents:  []
# sentence:  Atta boy, Dudley!`
# ents:  [Atta, Dudley]
# sentence:  He ruffled Dudley's
# ents:  [Dudley]
# subject:  He
# object:  Dudley
#
#  2  sentences in verse  86
# sentence:  hair.
# ents:  []
# sentence:  At that moment the telephone rang and Aunt Petunia
# ents:  []
# subject:  telephone
# object:  moment
#
#  1  sentences in verse  87
# sentence:  went to answer it while Harry and Uncle Vernon watched Dudley unwrap
# ents:  [Harry, Uncle Vernon, Dudley unwrap]
# subject:  Harry
# object:  Dudley
# Adding relation: ' harry ' -> ' dudley '
#
#  1  sentences in verse  88
# sentence:  the racing bike, a video camera, a remote control airplane, sixteen new
# ents:  [sixteen]
#
#  2  sentences in verse  89
# sentence:  computer games, and a VCR.
# ents:  []
# sentence:  He was ripping the paper off a gold
# ents:  []
# subject:  He
# object:  paper
# object:  gold
#
#  1  sentences in verse  90
# sentence:  wristwatch when Aunt Petunia came back from the telephone looking both angry
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
# subject:  telephone
#
#  3  sentences in verse  91
# sentence:  and worried.
# ents:  []
# sentence:  `Bad news, Vernon,` she said.
# ents:  [Vernon]
# subject:  news
# subject:  she
# sentence:  `Mrs. Figg's broken her
# ents:  [Figg]
# subject:  Figg
# Compounds:  ['Mrs.']
# object:  her
#
#  3  sentences in verse  92
# sentence:  leg.
# ents:  []
# sentence:  She can't take him.`
# ents:  []
# subject:  She
# object:  him
# sentence:  She jerked her head in Harry's direction.
# ents:  [Harry]
# subject:  She
# object:  head
# object:  direction
#
#  1  sentences in verse  93
# sentence:   Dudley's mouth fell open in horror, but Harry's heart gave a
# ents:  [Dudley, Harry]
# subject:  mouth
# object:  horror
# subject:  heart
# object:  a
#
#  2  sentences in verse  94
# sentence:  leap.
# ents:  []
# sentence:  Every year on Dudley's birthday, his parents took him and a
# ents:  [Every year, Dudley]
# subject:  parents
# object:  him
#
#  1  sentences in verse  95
# sentence:  friend out for the day, to adventure parks, hamburger restaurants, or the
# ents:  [the day]
#
#  2  sentences in verse  96
# sentence:  movies.
# ents:  []
# sentence:  Every year, Harry was left behind with Mrs. Figg, a mad
# ents:  [Every year, Harry, Figg]
# subject:  Harry
# object:  Figg
# Compounds:  ['Mrs.']
#
#  3  sentences in verse  97
# sentence:  old lady who lived two streets away.
# ents:  [two]
# subject:  who
# object:  streets
# sentence:  Harry hated it there.
# ents:  [Harry]
# subject:  Harry
# object:  it
# sentence:  The
# ents:  []
#
#  1  sentences in verse  98
# sentence:  whole house smelled of cabbage and Mrs. Figg made him look at
# ents:  [Figg]
# subject:  house
# Compounds:  ['whole']
# object:  cabbage
# subject:  Figg
# Compounds:  ['Mrs.']
# subject:  him
#
#  2  sentences in verse  99
# sentence:  photographs of all the cats she'd ever owned.
# ents:  []
# subject:  she
# sentence:  `Now what?` said
# ents:  []
#
#  2  sentences in verse  100
# sentence:  Aunt Petunia, looking furiously at Harry as though he'd planned this.
# ents:  [Harry]
# subject:  he
# object:  this
# sentence:  Harry
# ents:  [Harry]
#
#  1  sentences in verse  101
# sentence:  knew he ought to feel sorry that Mrs. Figg had broken her
# ents:  [Figg]
# subject:  he
# subject:  Figg
# Compounds:  ['Mrs.']
# object:  her
#
#  1  sentences in verse  102
# sentence:  leg, but it wasn't easy when he reminded himself it would be
# ents:  []
# subject:  it
# subject:  he
# object:  himself
# subject:  it
#
#  1  sentences in verse  103
# sentence:  a whole year before he had to look at Tibbles, Snowy, Mr.
# ents:  [a whole year, Tibbles, Snowy]
# subject:  he
#
#  2  sentences in verse  104
# sentence:  Paws, and Tufty again.
# ents:  [Tufty]
# sentence:  `We could phone Marge,` Uncle Vernon suggested.
# ents:  [Marge, Vernon]
# subject:  We
# object:  Marge
# subject:  Vernon
# Compounds:  ['Uncle']
#
#  2  sentences in verse  105
# sentence:   `Don't be silly, Vernon, she hates the boy.`
# ents:  [Vernon]
# subject:  she
# object:  boy
# sentence:  The Dursleys
# ents:  [Dursleys]
#
#  1  sentences in verse  106
# sentence:  often spoke about Harry like this, as though he wasn't there --
# ents:  [Harry]
# subject:  he
#
#  1  sentences in verse  107
# sentence:  or rather, as though he was something very nasty that couldn't understand
# ents:  []
# subject:  he
# subject:  that
#
#  2  sentences in verse  108
# sentence:  them, like a slug.
# ents:  []
# sentence:  `What about what's-her-name, your friend -- Yvonne?`
# ents:  [Yvonne]
#
#  3  sentences in verse  109
# sentence:
# ents:  []
# sentence:  `On vacation in Majorca,` snapped Aunt Petunia.
# ents:  [Majorca]
# subject:  Petunia
# Compounds:  ['Aunt']
# object:  vacation
# object:  Majorca
# sentence:  `You could just
# ents:  []
# subject:  You
#
#  1  sentences in verse  110
# sentence:  leave me here,` Harry put in hopefully (he'd be able to watch
# ents:  [Harry]
# subject:  Harry
# subject:  he
#
#  1  sentences in verse  111
# sentence:  what he wanted on television for a change and maybe even have
# ents:  []
# subject:  he
# object:  what
# object:  television
# object:  change
# Using conjunct subject:  he
#
#  2  sentences in verse  112
# sentence:  a go on Dudley's computer).
# ents:  [Dudley]
# sentence:  Aunt Petunia looked as though she'd
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
#
#  2  sentences in verse  113
# sentence:  just swallowed a lemon.
# ents:  []
# sentence:  `And come back and find the house
# ents:  []
#
#  2  sentences in verse  114
# sentence:  in ruins?` she snarled.
# ents:  []
# subject:  she
# object:  ruins
# sentence:  `I won't blow up the house,` said
# ents:  []
# subject:  I
# object:  house
#
#  2  sentences in verse  115
# sentence:  Harry, but they weren't listening.
# ents:  [Harry]
# subject:  they
# sentence:  `I suppose we could take him
# ents:  []
# subject:  I
# subject:  we
# object:  him
#
#  1  sentences in verse  116
# sentence:  to the zoo,` said Aunt Petunia slowly, `... and leave him in
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
# object:  zoo
# Using conjunct subject:  Petunia
# Compounds:  ['Aunt']
# object:  him
#
#  1  sentences in verse  117
# sentence:  the car....`  `That car's new, he's not sitting in it alone....`
# ents:  []
# subject:  he
# Negative adverb:  not .
# object:  it
# Reverting order of relation.
#
#  2  sentences in verse  118
# sentence:   Dudley began to cry loudly.
# ents:  [Dudley]
# subject:  Dudley
# sentence:  In fact, he wasn't really crying --
# ents:  []
# subject:  he
# object:  fact
#
#  1  sentences in verse  119
# sentence:  it had been years since he'd really cried -- but he knew
# ents:  [years]
# subject:  it
# subject:  he
# subject:  he
#
#  1  sentences in verse  120
# sentence:  that if he screwed up his face and wailed, his mother would
# ents:  []
# subject:  he
# object:  face
# Using conjunct subject:  he
#
#  2  sentences in verse  121
# sentence:  give him anything he wanted.
# ents:  []
# subject:  he
# sentence:  `Dinky Duddydums, don't cry, Mummy won't
# ents:  [`Dinky Duddydums, Mummy]
# subject:  Duddydums
# Compounds:  ['Dinky']
# subject:  Mummy
#
#  2  sentences in verse  122
# sentence:  let him spoil your special day!`
# ents:  []
# subject:  him
# object:  day
# Compounds:  ['special']
# sentence:  she cried, flinging her arms around
# ents:  []
# subject:  she
#
#  3  sentences in verse  123
# sentence:  him.
# ents:  []
# sentence:  `I... don't... want... him... t-t-to come!`
# ents:  []
# subject:  I
# object:  him
# subject:  t
# Compounds:  ['t']
# sentence:  Dudley yelled between huge,
# ents:  [Dudley]
# subject:  Dudley
#
#  3  sentences in verse  124
# sentence:  pretend sobs.
# ents:  []
# sentence:  `He always sp- spoils everything!`
# ents:  []
# subject:  He
# object:  everything
# sentence:  He shot Harry a nasty
# ents:  [Harry]
# subject:  He
# object:  Harry
# object:  nasty
#
#  2  sentences in verse  125
# sentence:  grin through the gap in his mother's arms.
# ents:  []
# sentence:  Just then, the
# ents:  []
#
#  1  sentences in verse  126
# sentence:  doorbell rang -- `Oh, good Lord, they're here!` said Aunt Petunia frantically
# ents:  [doorbell rang]
# subject:  doorbell
# subject:  they
# subject:  Petunia
# Compounds:  ['Aunt']
#
#  1  sentences in verse  127
# sentence:  -- and a moment later, Dudley's best friend, Piers Polkiss, walked in
# ents:  [Dudley, Piers Polkiss]
# subject:  friend
# Compounds:  ['best']
#
#  2  sentences in verse  128
# sentence:  with his mother.
# ents:  []
# sentence:  Piers was a scrawny boy with a face like
# ents:  [Piers]
# subject:  Piers
#
#  2  sentences in verse  129
# sentence:  a rat.
# ents:  []
# sentence:  He was usually the one who held people's arms behind
# ents:  []
# subject:  He
# subject:  who
# object:  arms
#
#  2  sentences in verse  130
# sentence:  their backs while Dudley hit them.
# ents:  [Dudley]
# subject:  Dudley
# object:  them
# sentence:  Dudley stopped pretending to cry at
# ents:  [Dudley]
# subject:  Dudley
#
#  2  sentences in verse  131
# sentence:  once.
# ents:  []
# sentence:  Half an hour later, Harry, who couldn't believe his luck,
# ents:  [Half an hour later, Harry]
# subject:  who
# object:  luck
#
#  1  sentences in verse  132
# sentence:  was sitting in the back of the Dursleys' car with Piers and
# ents:  [Dursleys, Piers]
#
#  1  sentences in verse  133
# sentence:  Dudley, on the way to the zoo for the first time in
# ents:  [Dudley, first]
#
#  2  sentences in verse  134
# sentence:  his life.
# ents:  []
# sentence:  His aunt and uncle hadn't been able to think of
# ents:  []
# subject:  aunt
#
#  1  sentences in verse  135
# sentence:  anything else to do with him, but before they'd left, Uncle Vernon
# ents:  [Uncle Vernon]
# subject:  they
#
#  2  sentences in verse  136
# sentence:  had taken Harry aside.
# ents:  [Harry]
# sentence:  `I'm warning you,` he had said, putting
# ents:  []
# subject:  I
# object:  you
# subject:  he
#
#  1  sentences in verse  137
# sentence:  his large purple face right up close to Harry's, `I'm warning you
# ents:  [Harry's]
# subject:  I
# object:  you
#
#  1  sentences in verse  138
# sentence:  now, boy -- any funny business, anything at all -- and you'll
# ents:  []
#
#  2  sentences in verse  139
# sentence:  be in that cupboard from now until Christmas.`
# ents:  [Christmas]
# sentence:  `I'm not going
# ents:  []
# subject:  I
# Negative adverb:  not .
#
#  3  sentences in verse  140
# sentence:  to do anything
# ents:  []
# sentence:  ,` said Harry, `honestly..
# ents:  [Harry]
# subject:  Harry
# sentence:  But Uncle Vernon didn't believe
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
#
#  3  sentences in verse  141
# sentence:  him.
# ents:  []
# sentence:  No one ever did.
# ents:  []
# subject:  one
# Negative subject determiner:  No .
# sentence:  The problem was, strange things often
# ents:  []
# subject:  problem
#
#  1  sentences in verse  142
# sentence:  happened around Harry and it was just no good telling the Dursleys
# ents:  [Harry, Dursleys]
# subject:  it
#
#  2  sentences in verse  143
# sentence:  he didn't make them happen.
# ents:  []
# subject:  he
# subject:  them
# sentence:  Once, Aunt Petunia, tired of Harry
# ents:  [Harry]
#
#  1  sentences in verse  144
# sentence:  coming back from the barbers looking as though he hadn't been at
# ents:  []
# subject:  he
#
#  1  sentences in verse  145
# sentence:  all, had taken a pair of kitchen scissors and cut his hair
# ents:  []
#
#  2  sentences in verse  146
# sentence:  so short he was almost bald except for his bangs,
# ents:  []
# subject:  he
# sentence:  which she
# ents:  []
#
#  2  sentences in verse  147
# sentence:  left `to hide that horrible scar.`
# ents:  []
# sentence:  Dudley had laughed himself silly at
# ents:  [Dudley]
# subject:  Dudley
# object:  himself
#
#  1  sentences in verse  148
# sentence:  Harry, who spent a sleepless night imagining school the next day, where he
# ents:  [Harry, the next day]
# subject:  who
# object:  night
# Compounds:  ['sleepless']
#
#  2  sentences in verse  149
# sentence:  was already laughed at for his baggy clothes and taped glasses.
# ents:  []
# sentence:  Next
# ents:  []
#
#  1  sentences in verse  150
# sentence:  morning, however, he had gotten up to find his hair exactly as
# ents:  [morning]
# subject:  he
#
#  1  sentences in verse  151
# sentence:  it had been before Aunt Petunia had sheared it off He had
# ents:  []
# subject:  it
# subject:  Petunia
# Compounds:  ['Aunt']
# object:  it
# subject:  He
#
#  1  sentences in verse  152
# sentence:  been given a week in his cupboard for this, even though he
# ents:  [a week]
#
#  1  sentences in verse  153
# sentence:  had tried to explain that he couldn't explain how it had grown
# ents:  []
# subject:  he
# subject:  it
#
#  2  sentences in verse  154
# sentence:  back so quickly.
# ents:  []
# sentence:  Another time, Aunt Petunia had been trying to
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
#
#  1  sentences in verse  155
# sentence:  force him into a revolting old sweater of Dudley's (brown with orange
# ents:  [Dudley]
#
#  2  sentences in verse  156
# sentence:  puff balls) --
# ents:  []
# sentence:  The harder she tried to pull it over his
# ents:  []
# subject:  she
#
#  1  sentences in verse  157
# sentence:  head, the smaller it seemed to become, until finally it might have
# ents:  []
# subject:  it
# subject:  it
#
#  2  sentences in verse  158
# sentence:  fitted a hand puppet, but certainly wouldn't fit Harry.
# ents:  [Harry]
# sentence:  Aunt Petunia had
# ents:  []
# subject:  Petunia
# Compounds:  ['Aunt']
#
#  1  sentences in verse  159
# sentence:  decided it must have shrunk in the wash and, to his great
# ents:  []
# subject:  it
# object:  wash
# object:  great
#
#  2  sentences in verse  160
# sentence:  relief, Harry wasn't punished.
# ents:  [Harry]
# subject:  Harry
# sentence:  On the other hand, he'd gotten into
# ents:  []
# subject:  he
# object:  hand
# Compounds:  ['other']
#
#  1  sentences in verse  161
# sentence:  terrible trouble for being found on the roof of the school kitchens.
# ents:  []
#
#  1  sentences in verse  162
# sentence:  Dudley's gang had been chasing him as usual when, as much to
# ents:  [Dudley]
# subject:  gang
# object:  him
#
#  1  sentences in verse  163
# sentence:  Harry's surprise as anyone else's, there he was sitting on the chimney.
# ents:  [Harry]
# subject:  surprise
# subject:  he
# object:  chimney
#
#  1  sentences in verse  164
# sentence:  The Dursleys had received a very angry letter from Harry's headmistress telling
# ents:  [Dursleys, Harry]
# subject:  Dursleys
# object:  letter
# Compounds:  ['angry']
# object:  headmistress
#
#  3  sentences in verse  165
# sentence:  them
# ents:  []
# sentence:  Harry had been climbing school buildings.
# ents:  [Harry]
# subject:  Harry
# object:  buildings
# Compounds:  ['school']
# sentence:  But all he'd tried to
# ents:  []
# subject:  he
#
#  1  sentences in verse  166
# sentence:  do (as he shouted at Uncle Vernon through the locked door of
# ents:  [Uncle Vernon]
# subject:  he
# object:  Vernon
# Compounds:  ['Uncle']
# object:  door
# Compounds:  ['locked']
#
#  1  sentences in verse  167
# sentence:  his cupboard) was jump behind the big trash cans outside the kitchen
# ents:  []
# subject:  cupboard
#
#  2  sentences in verse  168
# sentence:  doors.
# ents:  []
# sentence:  Harry supposed that the wind must have caught him in mid-
# ents:  [Harry]
# subject:  Harry
# subject:  wind
# object:  him
# object:  mid-
#
#  3  sentences in verse  169
# sentence:  jump.
# ents:  []
# sentence:  But today, nothing was going to go wrong.
# ents:  [today]
# subject:  nothing
# sentence:  It was
# ents:  []
# subject:  It
#
#  1  sentences in verse  170
# sentence:  even worth being with Dudley and Piers to be spending the day
# ents:  [Dudley, Piers, the day]
#
#  1  sentences in verse  171
# sentence:  somewhere that wasn't school, his cupboard, or Mrs. Figg's cabbage-smelling living room.
# ents:  [Figg]
# subject:  that
#
#  3  sentences in verse  172
# sentence:
# ents:  []
# sentence:  While he drove, Uncle Vernon complained to Aunt Petunia.
# ents:  [Uncle Vernon]
# subject:  he
# subject:  Vernon
# Compounds:  ['Uncle']
# object:  Petunia
# Compounds:  ['Aunt']
# Adding relation: ' uncle vernon ' -> ' aunt petunia '
# sentence:  He liked
# ents:  []
# subject:  He
#
#  1  sentences in verse  173
# sentence:  to complain about things: people at work, Harry, the council, Harry, the
# ents:  [Harry, Harry]
#
#  2  sentences in verse  174
# sentence:  bank, and Harry were just a few of his favorite subjects.
# ents:  [Harry]
# subject:  bank
# subject:  Harry
# sentence:  This
# ents:  []
#
#  2  sentences in verse  175
# sentence:  morning, it was motorcycles.
# ents:  []
# subject:  it
# sentence:  `... roaring along like maniacs, the young
# ents:  []
#
#  2  sentences in verse  176
# sentence:  hoodlums,` he said, as a motorcycle overtook them.
# ents:  []
# subject:  he
# subject:  motorcycle
# object:  them
# sentence:  I had a
# ents:  []
# subject:  I
# object:  a
#
#  2  sentences in verse  177
# sentence:  dream about a motorcycle,` said Harry, remembering suddenly.
# ents:  [Harry]
# subject:  Harry
# sentence:  `It was flying.`
# ents:  []
# subject:  It
#
#  2  sentences in verse  178
# sentence:  Uncle Vernon nearly crashed into the car in front.
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# object:  car
# Adding relation: ' uncle vernon ' -> ' car '
# object:  front
# sentence:  He turned right around
# ents:  []
# subject:  He
#
#  1  sentences in verse  179
# sentence:  in his seat and yelled at Harry, his face like a gigantic
# ents:  [Harry]
#
#  2  sentences in verse  180
# sentence:  beet with a mustache: `MOTORCYCLES DON'T FLY!`
# ents:  []
# sentence:  Dudley and Piers sniggered.
# ents:  [Dudley, Piers]
# subject:  Dudley
#
#  3  sentences in verse  181
# sentence:
# ents:  []
# sentence:  I know they don't,` said Harry.
# ents:  [Harry]
# subject:  I
# subject:  they
# subject:  Harry
# sentence:  `It was only a dream.`
# ents:  []
# subject:  It
#
#  3  sentences in verse  182
# sentence:
# ents:  []
# sentence:  But he wished he hadn't said anything.
# ents:  []
# subject:  he
# subject:  he
# object:  anything
# sentence:  If there was one
# ents:  [one]
#
#  1  sentences in verse  183
# sentence:  thing the Dursleys hated even more than his asking questions, it was
# ents:  [Dursleys]
# subject:  Dursleys
# subject:  it
#
#  1  sentences in verse  184
# sentence:  his talking about anything acting in a way it shouldn't, no matter
# ents:  []
# subject:  his
# object:  anything
# subject:  it
#
#  1  sentences in verse  185
# sentence:  if it was in a dream or even a cartoon -- they
# ents:  []
# subject:  it
# object:  dream
#
#  2  sentences in verse  186
# sentence:  seemed to think he might get dangerous ideas.
# ents:  []
# subject:  he
# object:  ideas
# Compounds:  ['dangerous']
# sentence:  It was a
# ents:  []
# subject:  It
#
#  2  sentences in verse  187
# sentence:  very sunny Saturday and the zoo was crowded with families.
# ents:  [Saturday]
# subject:  zoo
# object:  families
# sentence:  The Dursleys
# ents:  [Dursleys]
#
#  1  sentences in verse  188
# sentence:  bought Dudley and Piers large chocolate ice creams at the entrance and
# ents:  [Dudley, Piers]
#
#  1  sentences in verse  189
# sentence:  then, because the smiling lady in the van had asked Harry what
# ents:  [Harry]
# subject:  lady
# Compounds:  ['smiling']
# object:  Harry
# object:  what
#
#  1  sentences in verse  190
# sentence:  he wanted before they could hurry him away, they bought him a
# ents:  []
# subject:  he
# subject:  they
# object:  him
# subject:  they
# dative:  him
# object:  a
#
#  2  sentences in verse  191
# sentence:  cheap lemon ice pop.
# ents:  []
# sentence:  It wasn't bad, either, Harry thought, licking it
# ents:  [Harry]
# subject:  It
# subject:  Harry
#
#  1  sentences in verse  192
# sentence:  as they watched a gorilla scratching its head who looked remarkably like
# ents:  []
# subject:  they
# object:  gorilla
# subject:  who
#
#  2  sentences in verse  193
# sentence:  Dudley, except that it wasn't blond.
# ents:  [Dudley]
# subject:  it
# sentence:  Harry had the best morning
# ents:  [Harry]
# subject:  Harry
# object:  morning
# Compounds:  ['best']
#
#  2  sentences in verse  194
# sentence:  he'd had in a long time.
# ents:  []
# subject:  he
# object:  time
# Compounds:  ['long']
# sentence:  He was careful to walk a
# ents:  []
# subject:  He
#
#  1  sentences in verse  195
# sentence:  little way apart from the Dursleys so that Dudley and Piers, who
# ents:  [Dursleys, Dudley, Piers]
#
#  1  sentences in verse  196
# sentence:  were starting to get bored with the animals by lunchtime, wouldn't fall
# ents:  []
#
#  2  sentences in verse  197
# sentence:  back on their favorite hobby of hitting him.
# ents:  []
# sentence:  They ate in the
# ents:  []
# subject:  They
# object:  the
#
#  2  sentences in verse  198
# sentence:  zoo restaurant, and when Dudley had a tantrum
# ents:  [Dudley]
# subject:  Dudley
# object:  tantrum
# sentence:  because his knickerbocker glory
# ents:  []
#
#  1  sentences in verse  199
# sentence:  didn't have enough ice cream on top, Uncle Vernon bought him another
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# dative:  him
# object:  another
#
#  2  sentences in verse  200
# sentence:  one and Harry was allowed to finish the first.
# ents:  [one, Harry, first]
# subject:  one
# sentence:  Harry felt,
# ents:  [Harry]
# subject:  Harry
#
#  1  sentences in verse  201
# sentence:  afterward, that he should have known it was all too good to
# ents:  []
# subject:  he
# subject:  it
#
#  3  sentences in verse  202
# sentence:  last.
# ents:  []
# sentence:  After lunch they went to the reptile house.
# ents:  []
# subject:  they
# object:  lunch
# object:  house
# Compounds:  ['reptile']
# sentence:  It was
# ents:  []
# subject:  It
#
#  1  sentences in verse  203
# sentence:  cool and dark in there, with lit windows all along the walls.
# ents:  []
#
#  1  sentences in verse  204
# sentence:  Behind the glass, all sorts of lizards and snakes were crawling and
# ents:  []
# subject:  sorts
# object:  glass
#
#  2  sentences in verse  205
# sentence:  slithering over bits of wood and stone.
# ents:  []
# sentence:  Dudley and Piers wanted to
# ents:  [Dudley, Piers]
# subject:  Dudley
#
#  2  sentences in verse  206
# sentence:  see huge, poisonous cobras and thick, man-crushing pythons.
# ents:  []
# sentence:  Dudley quickly found the
# ents:  [Dudley]
# subject:  Dudley
# object:  the
#
#  2  sentences in verse  207
# sentence:  largest snake in the place.
# ents:  []
# sentence:  It could have wrapped its body twice around
# ents:  []
# subject:  It
# object:  body
#
#  1  sentences in verse  208
# sentence:  Uncle Vernon's car and crushed it into a trash can -- but
# ents:  [Uncle Vernon's]
# subject:  car
# object:  it
# object:  can
# Compounds:  ['trash']
#
#  2  sentences in verse  209
# sentence:  at the moment it didn't look in the mood.
# ents:  []
# subject:  it
# object:  moment
# object:  mood
# sentence:  In fact, it
# ents:  []
#
#  2  sentences in verse  210
# sentence:  was fast asleep.
# ents:  []
# sentence:  Dudley stood with his nose pressed against the
# ents:  [Dudley]
# subject:  Dudley
# object:  nose
#
#  2  sentences in verse  211
# sentence:  glass, staring at the glistening brown coils.
# ents:  []
# sentence:  `Make it move,` he
# ents:  []
# subject:  it
#
#  2  sentences in verse  212
# sentence:  whined at his father.
# ents:  []
# sentence:  Uncle Vernon tapped on the glass, but the
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# object:  glass
# Adding relation: ' uncle vernon ' -> ' glass '
#
#  3  sentences in verse  213
# sentence:  snake didn't budge.
# ents:  []
# subject:  snake
# sentence:  `Do it again,` Dudley ordered.
# ents:  [Dudley]
# subject:  Dudley
# sentence:  Uncle Vernon rapped
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
#
#  1  sentences in verse  214
# sentence:  the glass smartly with his knuckles, but the snake just snoozed on.
# ents:  []
# subject:  glass
# subject:  snake
#
#  4  sentences in verse  215
# sentence:
# ents:  []
# sentence:  `This is boring,` Dudley moaned.
# ents:  [Dudley]
# subject:  This
# subject:  Dudley
# sentence:  He shuffled away.
# ents:  []
# subject:  He
# sentence:  Harry moved
# ents:  [Harry]
# subject:  Harry
#
#  2  sentences in verse  216
# sentence:  in front of the tank and looked intently at the snake.
# ents:  []
# sentence:  He
# ents:  []
#
#  1  sentences in verse  217
# sentence:  wouldn't have been surprised if it had died of boredom itself --
# ents:  []
# subject:  it
# object:  boredom
#
#  1  sentences in verse  218
# sentence:  no company except stupid people drumming their fingers on the glass trying
# ents:  []
# subject:  people
# Compounds:  ['stupid']
# object:  fingers
# object:  glass
# subject:  company
# Negative subject determiner:  no .
#
#  2  sentences in verse  219
# sentence:  to disturb it all day long.
# ents:  []
# sentence:  It was worse than having a
# ents:  []
# subject:  It
#
#  1  sentences in verse  220
# sentence:  cupboard as a bedroom, where the only visitor was Aunt Petunia hammering
# ents:  []
# subject:  visitor
# Compounds:  ['only']
# subject:  cupboard
#
#  1  sentences in verse  221
# sentence:  on the door to wake you up; at least he got to
# ents:  []
# subject:  he
#
#  2  sentences in verse  222
# sentence:  visit the rest of the house.
# ents:  []
# sentence:  The snake suddenly opened its
# ents:  []
# subject:  snake
# object:  its
#
#  2  sentences in verse  223
# sentence:  beady eyes.
# ents:  []
# sentence:  Slowly, very slowly, it raised its head until its eyes
# ents:  []
# subject:  it
# object:  head
# object:  eyes
#
#  3  sentences in verse  224
# sentence:  were on a level with Harry's.
# ents:  [Harry]
# sentence:  It winked.
# ents:  []
# subject:  It
# sentence:  Harry stared.
# ents:  [Harry]
# subject:  Harry
#
#  2  sentences in verse  225
# sentence:  Then he looked quickly around to see if anyone was watching.
# ents:  []
# subject:  he
# subject:  anyone
# sentence:  They
# ents:  []
#
#  3  sentences in verse  226
# sentence:  weren't.
# ents:  []
# sentence:  He looked back at the snake and winked, too.
# ents:  []
# subject:  He
# object:  snake
# Using conjunct subject:  He
# sentence:  The
# ents:  []
#
#  1  sentences in verse  227
# sentence:  snake jerked its head toward Uncle Vernon and Dudley, then raised its
# ents:  [Uncle Vernon, Dudley]
# subject:  snake
# object:  head
# Adding relation: ' snake ' -> ' head '
# object:  Vernon
# Compounds:  ['Uncle']
# Adding relation: ' snake ' -> ' uncle vernon '
# Adding relation: ' snake ' -> ' dudley '
# Using conjunct subject:  snake
# object:  its
#
#  2  sentences in verse  228
# sentence:  eyes to the ceiling.
# ents:  []
# sentence:  It gave Harry a look that said quite
# ents:  [Harry]
# subject:  It
# dative:  Harry
# object:  look
# subject:  that
#
#  2  sentences in verse  229
# sentence:  plainly:  `I get that all the time.
# ents:  []
# subject:  I
# object:  that
# sentence:  `I know,` Harry
# ents:  []
# subject:  I
# object:  Harry
#
#  1  sentences in verse  230
# sentence:  murmured through the glass, though he wasn't sure the snake could hear
# ents:  []
# subject:  he
# subject:  snake
#
#  4  sentences in verse  231
# sentence:  him
# ents:  []
# sentence:  .
# ents:  []
# sentence:  `It must be really annoying.`
# ents:  []
# subject:  It
# sentence:  The snake nodded vigorously.
# ents:  []
# subject:  snake
#
#  3  sentences in verse  232
# sentence:  `Where do you come from, anyway?`
# ents:  []
# subject:  you
# object:  Where
# sentence:  Harry asked.
# ents:  [Harry]
# subject:  Harry
# sentence:  The snake jabbed
# ents:  []
# subject:  snake
#
#  2  sentences in verse  233
# sentence:  its tail at a little sign next to the glass.
# ents:  []
# sentence:  Harry peered
# ents:  [Harry]
# subject:  Harry
#
#  3  sentences in verse  234
# sentence:  at it.
# ents:  []
# sentence:  Boa Constrictor, Brazil.
# ents:  [Boa Constrictor, Brazil]
# sentence:  `Was it nice there?`
# ents:  []
# subject:  it
#
#  1  sentences in verse  235
# sentence:  The boa constrictor jabbed its tail at the sign again and Harry
# ents:  [Harry]
# subject:  constrictor
# Compounds:  ['boa']
# object:  tail
# object:  sign
#
#  2  sentences in verse  236
# sentence:  read on: This specimen was bred in the zoo.
# ents:  []
# subject:  specimen
# object:  zoo
# sentence:  `Oh, I see
# ents:  []
# subject:  I
#
#  1  sentences in verse  237
# sentence:  -- so you've never been to Brazil?`  As the snake shook its
# ents:  [Brazil]
# subject:  you
# Negative adverb:  never .
# object:  Brazil
# Reverting order of relation.
# subject:  snake
# object:  its
#
#  1  sentences in verse  238
# sentence:  head, a deafening shout behind Harry made both of them jump.
# ents:  [Harry]
# subject:  head
# subject:  both
#
#  4  sentences in verse  239
# sentence:  `DUDLEY!
# ents:  [DUDLEY]
# sentence:  MR. DURSLEY!
# ents:  [DURSLEY]
# sentence:  COME AND LOOK AT THIS SNAKE!
# ents:  []
# sentence:  YOU WON'T BELIEVE
# ents:  []
# subject:  YOU
# object:  BELIEVE
#
#  1  sentences in verse  240
# sentence:  WHAT IT'S DOING!`  Dudley came waddling toward them as fast as
# ents:  [Dudley]
# subject:  IT
# object:  WHAT
# subject:  Dudley
#
#  2  sentences in verse  241
# sentence:  he could.
# ents:  []
# subject:  he
# sentence:  `Out of the way, you,` he said, punching Harry
# ents:  [Harry]
# subject:  you
# subject:  he
#
#  2  sentences in verse  242
# sentence:  in the ribs.
# ents:  []
# sentence:  Caught by surprise, Harry fell hard on the concrete
# ents:  [Harry]
# subject:  Harry
# object:  concrete
#
#  2  sentences in verse  243
# sentence:  floor.
# ents:  []
# sentence:  What came next happened so fast no one saw how it
# ents:  []
# subject:  What
# subject:  one
# Negative subject determiner:  no .
#
#  1  sentences in verse  244
# sentence:  happened -- one second, Piers and Dudley were leaning right up close
# ents:  [one second, Piers, Dudley]
# subject:  Piers
#
#  1  sentences in verse  245
# sentence:  to the glass, the next, they had leapt back with howls of
# ents:  []
# subject:  they
# object:  glass
# object:  howls
#
#  2  sentences in verse  246
# sentence:  horror.
# ents:  []
# sentence:  Harry sat up and gasped; the glass front of the
# ents:  [Harry]
# subject:  Harry
# Using conjunct subject:  Harry
#
#  2  sentences in verse  247
# sentence:  boa constrictor's tank had vanished.
# ents:  []
# subject:  tank
# sentence:  The great snake was uncoiling itself rapidly,
# ents:  []
# subject:  snake
# Compounds:  ['great']
# object:  itself
#
#  2  sentences in verse  248
# sentence:  slithering out onto the floor.
# ents:  []
# sentence:  People throughout the reptile house screamed and
# ents:  []
# subject:  People
#
#  2  sentences in verse  249
# sentence:  started running for the exits.
# ents:  []
# sentence:  As the snake slid swiftly past
# ents:  []
# subject:  snake
#
#  1  sentences in verse  250
# sentence:  him, Harry could have sworn a low, hissing voice said, `Brazil, here
# ents:  [Harry, Brazil]
# subject:  Harry
# object:  Brazil
# subject:  voice
# Compounds:  ['low', 'hissing']
#
#  3  sentences in verse  251
# sentence:  I come....
# ents:  []
# subject:  I
# sentence:  Thanksss, amigo.`
# ents:  []
# sentence:  The keeper of the reptile house was
# ents:  []
# subject:  keeper
#
#  2  sentences in verse  252
# sentence:  in shock.
# ents:  []
# sentence:  `But the glass,` he kept saying, `where did the
# ents:  []
# subject:  he
# subject:  glass
#
#  2  sentences in verse  253
# sentence:  glass go?`
# ents:  []
# subject:  glass
# sentence:  The zoo director himself made Aunt Petunia a cup
# ents:  []
# subject:  director
# Compounds:  ['zoo']
#
#  2  sentences in verse  254
# sentence:  of strong, sweet tea while he apologized over and over again.
# ents:  []
# subject:  he
# sentence:  Piers
# ents:  [Piers]
#
#  2  sentences in verse  255
# sentence:  and Dudley could only gibber.
# ents:  [Dudley]
# subject:  Dudley
# sentence:  As far as Harry had seen, the
# ents:  [Harry]
# subject:  Harry
#
#  1  sentences in verse  256
# sentence:  snake hadn't done anything except snap playfully at their heels as it
# ents:  []
# subject:  snake
# object:  anything
# Adding relation: ' snake ' -> ' anything '
#
#  1  sentences in verse  257
# sentence:  passed, but by the time they were all back in Uncle Vernon's
# ents:  [Uncle Vernon's]
# subject:  they
# object:  time
#
#  1  sentences in verse  258
# sentence:  car, Dudley was telling them how it had nearly bitten off his
# ents:  [Dudley]
# subject:  Dudley
# object:  them
# object:  his
# subject:  it
#
#  1  sentences in verse  259
# sentence:  leg, while Piers was swearing it had tried to squeeze him to
# ents:  [Piers]
# subject:  Piers
# object:  it
# subject:  leg
#
#  2  sentences in verse  260
# sentence:  death.
# ents:  []
# sentence:  But worst of all, for Harry at least, was Piers calming
# ents:  [Harry, Piers]
# subject:  worst
# subject:  Harry
# subject:  Piers
#
#  1  sentences in verse  261
# sentence:  down enough to say, `Harry was talking to it, weren't you, Harry?`
# ents:  [Harry, Harry]
# subject:  Harry
# object:  it
# subject:  you
#
#  1  sentences in verse  262
# ...
# subject:  He
# object:  Hagrid
#
#  2  sentences in verse  860
# sentence:  his fists were clenched.
# ents:  []
# subject:  fists
# sentence:  `Now, you listen here, boy,` he snarled,
# ents:  []
# subject:  you
# subject:  he
#
#  1  sentences in verse  861
# sentence:  `I accept there's something strange about you, probably nothing a good beating
# ents:  []
# subject:  I
#
#  1  sentences in verse  862
# sentence:  wouldn't have cured -- and as for all this about your parents,
# ents:  []
#
#  2  sentences in verse  863
# sentence:  well, they were weirdos, no denying it, and
# ents:  []
# subject:  they
# sentence:  the world's better off
# ents:  []
#
#  1  sentences in verse  864
# sentence:  without them in my opinion -- asked for all they got, getting
# ents:  []
# subject:  they
#
#  1  sentences in verse  865
# sentence:  mixed up with these wizarding types -- just what I expected, always
# ents:  []
# subject:  I
# object:  what
#
#  2  sentences in verse  866
# sentence:  knew they'd come to a sticky end --`
# ents:  []
# subject:  they
# object:  end
# Compounds:  ['sticky']
# sentence:  But at that
# ents:  []
#
#  1  sentences in verse  867
# sentence:  moment, Hagrid leapt from the sofa and drew a battered pink umbrella
# ents:  []
# subject:  Hagrid
# object:  sofa
# Using conjunct subject:  Hagrid
# object:  umbrella
# Compounds:  ['battered', 'pink']
#
#  2  sentences in verse  868
# sentence:  from inside his coat.
# ents:  []
# sentence:  Pointing this at Uncle Vernon like a sword,
# ents:  [Uncle Vernon]
#
#  1  sentences in verse  869
# sentence:  he said, `I'm warning you, Dursley -I'm warning you -- one more
# ents:  [Dursley, one]
# subject:  he
# subject:  I
# object:  you
#
#  2  sentences in verse  870
# sentence:  word... `
# ents:  []
# sentence:  In danger of being speared on the end of
# ents:  []
#
#  1  sentences in verse  871
# sentence:  an umbrella by a bearded giant, Uncle Vernon's courage failed again; he
# ents:  [Uncle Vernon's]
# subject:  umbrella
# subject:  courage
#
#  2  sentences in verse  872
# sentence:  flattened himself against the wall and fell silent.
# ents:  []
# sentence:  `That's better,` said
# ents:  []
# subject:  That
#
#  1  sentences in verse  873
# sentence:  Hagrid, breathing heavily and sitting back down on the sofa, which this
# ents:  []
#
#  2  sentences in verse  874
# sentence:  time sagged right down to the floor.
# ents:  []
# subject:  time
# sentence:  Harry, meanwhile, still had
# ents:  [Harry]
# subject:  Harry
#
#  2  sentences in verse  875
# sentence:  questions to ask, hundreds of them.
# ents:  [hundreds]
# sentence:  `But what happened to Vol--,
# ents:  [Vol--]
# subject:  what
# object:  Vol--
#
#  3  sentences in verse  876
# sentence:  sorry -- I mean, You-Know-Who?`  `Good question, Harry. Disappeared.
# ents:  [Harry]
# subject:  I
# subject:  question
# Compounds:  ['Good']
# sentence:  Vanished.
# ents:  []
# sentence:  Same
# ents:  []
#
#  3  sentences in verse  877
# sentence:  night he tried ter kill you.
# ents:  [ter]
# subject:  he
# object:  ter
# sentence:  Makes yeh even more famous.
# ents:  []
# sentence:  That's
# ents:  []
# subject:  That
#
#  1  sentences in verse  878
# sentence:  the biggest myst'ry, see... he was gettin' more an' more powerful --
# ents:  []
# subject:  myst'ry
# Compounds:  ['biggest']
# subject:  he
#
#  3  sentences in verse  879
# sentence:  why'd he go?
# ents:  []
# subject:  he
# sentence:  `Some say he died.
# ents:  []
# subject:  Some
# subject:  he
# sentence:  Codswallop, in my opinion.
# ents:  [Codswallop]
#
#  2  sentences in verse  880
# sentence:  Dunno if he had enough human left in him to die.
# ents:  []
# subject:  he
# object:  human
# Compounds:  ['enough']
# sentence:  Some
# ents:  []
#
#  1  sentences in verse  881
# sentence:  say he's still out there, bidin' his time, like, but I don'
# ents:  [bidin]
# subject:  he
# subject:  I
#
#  2  sentences in verse  882
# sentence:  believe it.
# ents:  []
# sentence:  People who was on his side came back ter ours.
# ents:  []
# subject:  who
# object:  side
# subject:  People
#
#  2  sentences in verse  883
# sentence:  Some of 'em came outta kinda trances.
# ents:  []
# subject:  Some
# sentence:  Don~ reckon they could've done
# ents:  [Don~]
# subject:  Don~
# subject:  they
#
#  2  sentences in verse  884
# sentence:  if he was comin' back.
# ents:  []
# subject:  he
# sentence:  `Most of us reckon he's still
# ents:  []
# subject:  Most
# subject:  he
#
#  2  sentences in verse  885
# sentence:  out there somewhere but lost his powers.
# ents:  []
# sentence:  Too weak to carry on.
# ents:  []
#
#  2  sentences in verse  886
# sentence:  'Cause somethin' about you finished him, Harry.
# ents:  [Harry]
# subject:  somethin'
# object:  him
# sentence:  There was somethin' goin' on
# ents:  []
# subject:  somethin'
#
#  1  sentences in verse  887
# sentence:  that night he hadn't counted on -- I dunno what it was,
# ents:  []
# subject:  he
# subject:  I
# subject:  it
#
#  1  sentences in verse  888
# sentence:  no one does -- but somethin' about you stumped him, all right.`
# ents:  []
# subject:  one
# Negative subject determiner:  no .
# subject:  somethin'
# object:  him
#
#  1  sentences in verse  889
# sentence:   Hagrid looked at Harry with warmth and respect blazing in his
# ents:  [Harry]
# subject:  Hagrid
# object:  Harry
# Adding relation: ' hagrid ' -> ' harry '
# object:  warmth
#
#  1  sentences in verse  890
# sentence:  eyes, but Harry, instead of feeling pleased and proud, felt quite sure
# ents:  [Harry]
# subject:  eyes
#
#  4  sentences in verse  891
# sentence:  there had been a horrible mistake.
# ents:  []
# sentence:  A wizard?
# ents:  []
# sentence:  Him?
# ents:  []
# sentence:  How could he
# ents:  []
#
#  2  sentences in verse  892
# sentence:  possibly be?
# ents:  []
# sentence:  He'd spent his life being clouted by Dudley, and bullied
# ents:  [Dudley]
# subject:  He
# object:  life
# Using conjunct subject:  He
#
#  1  sentences in verse  893
# sentence:  by Aunt Petunia and Uncle Vernon; if he was really a wizard,
# ents:  [Uncle Vernon]
# subject:  he
#
#  1  sentences in verse  894
# sentence:  why hadn't they been turned into warty toads every time they'd tried
# ents:  []
# subject:  they
# object:  toads
# Compounds:  ['warty']
# subject:  they
#
#  2  sentences in verse  895
# sentence:  to lock him in his cupboard?
# ents:  []
# sentence:  If he'd once defeated the greatest
# ents:  []
# subject:  he
# object:  greatest
#
#  1  sentences in verse  896
# sentence:  sorcerer in the world, how come Dudley had always been able to
# ents:  [Dudley]
# subject:  Dudley
#
#  2  sentences in verse  897
# sentence:  kick him around like a football?
# ents:  []
# sentence:  `Hagrid,` he said quietly, `I
# ents:  []
# subject:  he
# object:  I
#
#  2  sentences in verse  898
# sentence:  think you must have made a mistake.
# ents:  []
# subject:  you
# object:  mistake
# sentence:  I don't think I can
# ents:  []
# subject:  I
# subject:  I
#
#  2  sentences in verse  899
# sentence:  be a wizard.`  To his surprise, Hagrid chuckled.
# ents:  []
# subject:  Hagrid
# object:  surprise
# sentence:  `Not a
# ents:  []
#
#  2  sentences in verse  900
# sentence:  wizard, eh?
# ents:  []
# sentence:  Never made things happen when you was scared or angry?`
# ents:  []
# subject:  things
# subject:  you
#
#  2  sentences in verse  901
# sentence:   Harry looked into the fire.
# ents:  []
# subject:  Harry
# object:  fire
# sentence:  Now he came to think about
# ents:  []
# subject:  he
#
#  1  sentences in verse  902
# sentence:  it... every odd thing that had ever made his aunt and uncle
# ents:  []
# subject:  that
# object:  aunt
#
#  1  sentences in verse  903
# sentence:  furious with him had happened when he, Harry, had been upset or
# ents:  [Harry]
# subject:  he
#
#  1  sentences in verse  904
# sentence:  angry... chased by Dudley's gang, he had somehow found himself out of
# ents:  [Dudley]
# subject:  he
# object:  himself
#
#  1  sentences in verse  905
# sentence:  their reach... dreading going to school with that ridiculous haircut, he'd managed
# ents:  []
# subject:  he
#
#  1  sentences in verse  906
# sentence:  to make it grow back... and the very last time Dudley had
# ents:  [Dudley]
# subject:  it
# subject:  Dudley
#
#  1  sentences in verse  907
# sentence:  hit him, hadn't he got his revenge, without even realizing he was
# ents:  []
# subject:  he
# object:  revenge
# subject:  he
#
#  3  sentences in verse  908
# sentence:  doing it?
# ents:  []
# sentence:  Hadn't he set a boa constrictor on him?
# ents:  []
# subject:  he
# object:  constrictor
# Compounds:  ['boa']
# object:  him
# sentence:  Harry
# ents:  [Harry]
#
#  1  sentences in verse  909
# sentence:  looked back at Hagrid, smiling, and saw that Hagrid was positively beaming
# ents:  [Hagrid, Hagrid]
# subject:  Hagrid
#
#  3  sentences in verse  910
# sentence:  at him.
# ents:  []
# sentence:  `See?` said Hagrid.
# ents:  []
# subject:  Hagrid
# sentence:  `Harry Potter, not a wizard --
# ents:  [Harry Potter]
#
#  2  sentences in verse  911
# sentence:  you wait, you'll be right famous at Hogwarts.`
# ents:  [Hogwarts]
# subject:  you
# subject:  you
# object:  Hogwarts
# sentence:  But Uncle Vernon
# ents:  [Uncle Vernon]
#
#  2  sentences in verse  912
# sentence:  wasn't going to give in without a fight.
# ents:  []
# sentence:  `Haven't I told
# ents:  []
# subject:  I
#
#  2  sentences in verse  913
# sentence:  you he's not going?` he hissed.
# ents:  []
# subject:  he
# Negative adverb:  not .
# subject:  he
# sentence:  `He's going to Stonewall High and
# ents:  []
# subject:  He
# object:  High
# Compounds:  ['Stonewall']
#
#  2  sentences in verse  914
# sentence:  he'll be grateful for it.
# ents:  []
# subject:  he
# sentence:  I've read those letters and he needs
# ents:  []
# subject:  I
# object:  letters
# subject:  he
#
#  1  sentences in verse  915
# sentence:  all sorts of rubbish -- spell books and wands and --`
# ents:  []
#
#  1  sentences in verse  916
# sentence:  `If he wants ter go, a great Muggle like you won't stop
# ents:  [ter]
# subject:  he
# subject:  ter
# subject:  you
#
#  2  sentences in verse  917
# sentence:  him,` growled Hagrid.
# ents:  []
# subject:  him
# object:  Hagrid
# sentence:  `Stop Lily an' James Potter' s son goin' ter
# ents:  [James Potter']
# subject:  son
# Compounds:  ['s']
#
#  3  sentences in verse  918
# sentence:  Hogwarts!
# ents:  []
# sentence:  Yer mad.
# ents:  []
# sentence:  His name's been down ever since he was born.
# ents:  []
# subject:  name
# subject:  he
#
#  1  sentences in verse  919
# sentence:  He's off ter the finest school of witchcraft and wizardry in the
# ents:  []
# subject:  He
# object:  ter
#
#  3  sentences in verse  920
# sentence:  world.
# ents:  []
# sentence:  Seven years there and he won't know himself.
# ents:  [Seven years]
# subject:  he
# object:  himself
# sentence:  He'll be with
# ents:  []
# subject:  He
#
#  1  sentences in verse  921
# sentence:  youngsters of his own sort, fer a change, an' he'll be under
# ents:  []
# subject:  he
# object:  an
#
#  1  sentences in verse  922
# sentence:  the greatest headmaster Hogwarts ever had Albus Dumbled--`  `I AM NOT
# ents:  [Hogwarts, Albus]
# subject:  headmaster
# Compounds:  ['greatest']
# object:  Dumbled--
# Compounds:  ['Albus']
# subject:  I
# Negative adverb:  NOT .
#
#  1  sentences in verse  923
# sentence:  PAYING FOR SOME CRACKPOT OLD FOOL To TEACH HIM MAGIC TRICKS!` yelled
# ents:  []
#
#  3  sentences in verse  924
# sentence:  Uncle Vernon.
# ents:  [Uncle Vernon]
# sentence:  But he had finally gone too far.
# ents:  []
# subject:  he
# sentence:  Hagrid seized
# ents:  []
# subject:  Hagrid
#
#  1  sentences in verse  925
# sentence:  his umbrella and whirled it over his head, `NEVER,` he thundered, `-
# ents:  []
# subject:  umbrella
# object:  it
# object:  head
# subject:  he
#
#  3  sentences in verse  926
# sentence:  INSULT- ALBUS- DUMBLEDORE- IN- FRONT-
# ents:  [IN- FRONT-]
# sentence:  OF- ME!`
# ents:  []
# sentence:  He brought the umbrella
# ents:  []
# subject:  He
# object:  umbrella
#
#  1  sentences in verse  927
# sentence:  swishing down through the air to point at Dudley -- there was
# ents:  [Dudley]
#
#  1  sentences in verse  928
# sentence:  a flash of violet light, a sound like a firecracker, a sharp
# ents:  []
#
#  1  sentences in verse  929
# sentence:  squeal, and the next second, Dudley was dancing on the spot with
# ents:  [Dudley]
# subject:  Dudley
# object:  spot
#
#  2  sentences in verse  930
# sentence:  his hands clasped over his fat bottom, howling in pain.
# ents:  []
# subject:  hands
# object:  bottom
# Compounds:  ['fat']
# sentence:  When he
# ents:  []
#
#  1  sentences in verse  931
# sentence:  turned his back on them, Harry saw a curly pig's tail poking
# ents:  [Harry]
# subject:  Harry
#
#  3  sentences in verse  932
# sentence:  through a hole in his trousers.
# ents:  []
# sentence:  Uncle Vernon roared.
# ents:  [Uncle Vernon]
# subject:  Vernon
# Compounds:  ['Uncle']
# sentence:  Pulling Aunt
# ents:  []
#
#  1  sentences in verse  933
# sentence:  Petunia and Dudley into the other room, he cast one last terrified
# ents:  [Petunia, Dudley, one]
# subject:  he
# object:  one
#
#  2  sentences in verse  934
# sentence:  look at Hagrid and slammed the door behind them.
# ents:  [Hagrid]
# sentence:  Hagrid looked
# ents:  []
# subject:  Hagrid
#
#  2  sentences in verse  935
# sentence:  down at his umbrella and stroked his beard.
# ents:  []
# sentence:  `Shouldn'ta lost me
# ents:  [Shouldn'ta]
# subject:  Shouldn'ta
# object:  me
#
#  2  sentences in verse  936
# sentence:  temper,` he said ruefully, `but it didn't work anyway.
# ents:  []
# subject:  temper
# subject:  he
# subject:  it
# sentence:  Meant ter turn
# ents:  [ter]
#
#  1  sentences in verse  937
# sentence:  him into a pig, but I suppose he was so much like
# ents:  []
# subject:  I
# subject:  he
#
#  2  sentences in verse  938
# sentence:  a pig anyway there wasn't much left ter do.`
# ents:  []
# subject:  ter
# sentence:  He cast
# ents:  []
# subject:  He
#
#  2  sentences in verse  939
# sentence:  a sideways look at Harry under his bushy eyebrows.
# ents:  [Harry]
# sentence:  `Be grateful
# ents:  []
#
#  2  sentences in verse  940
# sentence:  if yeh didn't mention that ter anyone at Hogwarts,` he said.
# ents:  [yeh, ter, Hogwarts]
# subject:  yeh
# object:  anyone
# Compounds:  ['ter']
# object:  Hogwarts
# subject:  he
# sentence:  `I'm
# ents:  []
# subject:  I
#
#  2  sentences in verse  941
# sentence:  -- er -- not supposed ter do magic, strictly speakin'.
# ents:  []
# subject:  ter
# object:  magic
# sentence:  I was
# ents:  []
# subject:  I
#
#  1  sentences in verse  942
# sentence:  allowed ter do a bit ter follow yeh an' get yer letters
# ents:  [ter, yeh]
# subject:  ter
#
#  1  sentences in verse  943
# sentence:  to yeh an' stuff -- one o' the reasons I was so
# ents:  [yeh]
# subject:  I
#
#  1  sentences in verse  944
# sentence:  keen ter take on the job  `Why aren't you supposed to
# ents:  [ter]
# subject:  ter
# object:  job
# subject:  you
#
#  2  sentences in verse  945
# sentence:  do magic?` asked Harry.
# ents:  [Harry]
# sentence:  `Oh, well -- I was at Hogwarts
# ents:  [Hogwarts]
# subject:  I
# object:  Hogwarts
#
#  1  sentences in verse  946
# sentence:  meself but I -- er -- got expelled, ter tell yeh the
# ents:  [ter, yeh]
# subject:  ter
# dative:  yeh
#
#  3  sentences in verse  947
# sentence:  truth.
# ents:  []
# sentence:  In me third year.
# ents:  [third year]
# sentence:  They snapped me wand in half an'
# ents:  [half]
# subject:  They
# object:  me
# object:  wand
# object:  an
#
#  3  sentences in verse  948
# sentence:  everything.
# ents:  []
# sentence:  But Dumbledore let me stay on as gamekeeper.
# ents:  [Dumbledore]
# subject:  Dumbledore
# subject:  me
# object:  gamekeeper
# sentence:  Great man, Dumbledore.`
# ents:  [Dumbledore]
#
#  1  sentences in verse  949
# sentence:  `Why were you expelled?`  `It's gettin' late and we've got lots
# ents:  []
# subject:  you
# subject:  It
# subject:  we
# object:  lots
#
#  2  sentences in verse  950
# sentence:  ter do tomorrow,` said Hagrid loudly.
# ents:  [tomorrow]
# subject:  ter
# subject:  Hagrid
# sentence:  `Gotta get up ter town, get
# ents:  []
#
#  2  sentences in verse  951
# sentence:  all yer books an' that.`
# ents:  []
# sentence:  He took off his thick black
# ents:  []
# subject:  He
# object:  black
# Compounds:  ['thick']
#
#  2  sentences in verse  952
# sentence:  coat and threw it to Harry.
# ents:  [Harry]
# sentence:  `You can kip under that,`
# ents:  []
# subject:  You
# object:  that
#
#  2  sentences in verse  953
# sentence:  he said.
# ents:  []
# subject:  he
# sentence:  `Don' mind if it wriggles a bit, I think I
# ents:  [Don]
# subject:  it
# subject:  mind
# subject:  I
# object:  I
#
#  1  sentences in verse  954
# sentence:  still got a couple o' dormice in one o' the pockets.`
# ents:  []
# Number of extracted relations:  42

# %%
# Run for each cluster
for cluster in range(1, num_topics + 1):
    print(f'Cluster: #{cluster}, cluster chapters: {clusters[cluster]}')
    cluster_chapters = clusters[cluster]
    cluster_titles = [titles[i] for i in cluster_chapters]
    
    text_per_chapter = []
    for idx in cluster_chapters:
        text_per_chapter.append(chapters[idx])
    
    tf_idf_pre_filtering = get_word_types_with_tf_idf(
        text_per_chapter,
        "tf",
        skip_stopwords=True,
        include_verbs=False,
        include_determiners=False,
        include_pronouns=False,
        include_adverbs=False,
        include_numbers=True,
    )
    
    print(tf_idf_pre_filtering.head(50))
    
    top_n_words = tf_idf_pre_filtering.head(50)["word"].values
    
    all_verses = []
    for chapter_idx in cluster_chapters:
        all_verses.extend(sentences_per_chapter[chapter_idx])
        
    directed_relations, relations_to_verbs = get_directed_relations(
        top_n_words=top_n_words,
        all_verses=all_verses,
        verbose=False,
    )
    ordered_directed_relations = order_directed_relations(
        directed_relations=directed_relations,
        tf_idf_pre_filtering=tf_idf_pre_filtering,
        order_by="product",
        include_ordering_wrt_occurences=True,
        verbose=False,
    )
    ontology_hierarchy, words_with_parents = construct_ontology_hierarchy(
        ordered_directed_relations=ordered_directed_relations,
    )
    
    draw_hierarchy_tree_from_ontology(
        ontological_hierarchy=ontology_hierarchy,
        relations_to_verbs=relations_to_verbs
    )
# Out:
# Cluster: #1, cluster chapters: [4, 7, 13, 14]
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tf = pd.concat([tf, row_df], ignore_index=True)
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   idf = pd.concat([idf, row_df], ignore_index=True)
#                      word                                          word_type  \
# 0                   harry  {'NNP': 316, 'ORGANIZATION': 9, 'PERSON': 313,...
# 1                  hagrid  {'NNP': 197, 'PERSON': 172, 'GPE': 30, 'JJ': 1...
# 3                hermione  {'NNP': 56, 'PERSON': 63, 'NN': 13, 'ORGANIZAT...
# 4                     ron  {'NNP': 59, 'PERSON': 55, 'ORGANIZATION': 3, '...
# 7                     one                                {'NN': 5, 'CD': 54}
# 12                   like                       {'IN': 39, 'VB': 4, 'JJ': 2}
# 13                  could                               {'MD': 56, 'NNP': 1}
# 15              professor  {'NNP': 38, 'PERSON': 15, 'ORGANIZATION': 8, '...
# 17                  snape                 {'NN': 8, 'PERSON': 32, 'NNP': 28}
# 20                 malfoy  {'NNP': 33, 'PERSON': 21, 'GPE': 12, 'VBN': 1,...
# 23                 potter                 {'NN': 3, 'PERSON': 26, 'NNP': 27}
# 25                   wand                                         {'NN': 29}
# 31                   eyes                                        {'NNS': 27}
# 33               quirrell       {'NNP': 27, 'PERSON': 17, 'ORGANIZATION': 8}
# 34                   time                                         {'NN': 26}
# 36                   head                      {'NN': 24, 'JJ': 1, 'NNP': 1}
# 39                norbert  {'NNP': 19, 'GPE': 10, 'CC': 1, 'NN': 2, 'PERS...
# 42                  would                                         {'MD': 40}
# 43                neville       {'NNP': 22, 'PERSON': 17, 'GPE': 5, 'RB': 3}
# 45                 dragon  {'VB': 1, 'NN': 20, 'NNP': 2, 'PERSON': 1, 'NN...
# 46                  magic  {'NN': 9, 'NNS': 2, 'NNP': 6, 'PERSON': 1, 'GP...
# 48                    two                                         {'CD': 23}
# 53                   good                                {'JJ': 20, 'NN': 1}
# 54                 forest  {'NNP': 2, 'ORGANIZATION': 1, 'NN': 13, 'JJS': 7}
# 55                   dark  {'NNP': 3, 'ORGANIZATION': 2, 'JJ': 11, 'NN': ...
# 57                 behind                      {'IN': 20, 'VB': 1, 'NNP': 1}
# 58               hogwarts  {'NNP': 13, 'PERSON': 3, 'ORGANIZATION': 9, 'J...
# 59                unicorn                                {'JJ': 20, 'NN': 1}
# 60                  night                                         {'NN': 21}
# 66                 people                                        {'NNS': 20}
# 69                    way                                         {'NN': 20}
# 70                  filch       {'NNP': 20, 'PERSON': 19, 'ORGANIZATION': 1}
# 73                 little                                {'JJ': 18, 'RB': 1}
# 74                   last                                         {'JJ': 18}
# 75                    yes             {'UH': 16, 'NN': 1, 'NNS': 1, 'RB': 1}
# 76               everyone                                {'NN': 18, 'JJ': 1}
# 78              gringotts  {'NNP': 19, 'PERSON': 8, 'GPE': 1, 'ORGANIZATI...
# 79                   fang  {'NNP': 17, 'PERSON': 15, 'GPE': 1, 'ORGANIZAT...
# 80                    boy                                {'UH': 2, 'NN': 16}
# 83             ollivander       {'NNP': 16, 'PERSON': 16, 'NN': 1, 'JJR': 1}
# 84                   hand                                         {'NN': 18}
# 85                   door                                         {'NN': 17}
# 88                 things                              {'NNS': 15, 'NNP': 2}
# 89                 school            {'NN': 14, 'NNP': 1, 'ORGANIZATION': 1}
# 90             mcgonagall        {'NNP': 17, 'ORGANIZATION': 4, 'PERSON': 6}
# 91                  stone                   {'NN': 8, 'NNP': 9, 'PERSON': 1}
# 93   professor mcgonagall  {'ORGANIZATION': 12, 'PERSON': 21, 'GPE': 1, '...
# 102                  must         {'JJ': 1, 'NNP': 1, 'PERSON': 1, 'MD': 13}
# 103                  fire                                {'NN': 14, 'VB': 1}
# 104                  next                                {'JJ': 14, 'RB': 1}
#
#       tc        tf dc       idf    tf_idf
# 0    334  0.017639  4  0.000000  0.000000
# 1    225  0.011883  4  0.000000  0.000000
# 3     70  0.003697  3  0.287682  0.001064
# 4     65  0.003433  3  0.287682  0.000988
# 7     61  0.003222  4  0.000000  0.000000
# 12    45  0.002377  4  0.000000  0.000000
# 13    41  0.002165  4  0.000000  0.000000
# 15    39  0.002060  4  0.000000  0.000000
# 17    37  0.001954  3  0.287682  0.000562
# 20    35  0.001848  3  0.287682  0.000532
# 23    34  0.001796  4  0.000000  0.000000
# 25    32  0.001690  3  0.287682  0.000486
# 31    27  0.001426  4  0.000000  0.000000
# 33    27  0.001426  4  0.000000  0.000000
# 34    26  0.001373  4  0.000000  0.000000
# 36    26  0.001373  4  0.000000  0.000000
# 39    25  0.001320  2  0.693147  0.000915
# 42    25  0.001320  4  0.000000  0.000000
# 43    25  0.001320  2  0.693147  0.000915
# 45    25  0.001320  3  0.287682  0.000380
# 46    24  0.001267  4  0.000000  0.000000
# 48    24  0.001267  4  0.000000  0.000000
# 53    23  0.001215  4  0.000000  0.000000
# 54    23  0.001215  4  0.000000  0.000000
# 55    22  0.001162  4  0.000000  0.000000
# 57    22  0.001162  4  0.000000  0.000000
# 58    21  0.001109  3  0.287682  0.000319
# 59    21  0.001109  2  0.693147  0.000769
# 60    21  0.001109  4  0.000000  0.000000
# 66    20  0.001056  4  0.000000  0.000000
# 69    20  0.001056  4  0.000000  0.000000
# 70    20  0.001056  3  0.287682  0.000304
# 73    19  0.001003  4  0.000000  0.000000
# 74    19  0.001003  3  0.287682  0.000289
# 75    19  0.001003  4  0.000000  0.000000
# 76    19  0.001003  4  0.000000  0.000000
# 78    19  0.001003  3  0.287682  0.000289
# 79    18  0.000951  3  0.287682  0.000273
# 80    18  0.000951  3  0.287682  0.000273
# 83    18  0.000951  1  1.386294  0.001318
# 84    18  0.000951  4  0.000000  0.000000
# 85    17  0.000898  4  0.000000  0.000000
# 88    17  0.000898  4  0.000000  0.000000
# 89    17  0.000898  4  0.000000  0.000000
# 90    17  0.000898  3  0.287682  0.000258
# 91    17  0.000898  4  0.000000  0.000000
# 93    16  0.000845  3  0.287682  0.000243
# 102   16  0.000845  3  0.287682  0.000243
# 103   15  0.000792  4  0.000000  0.000000
# 104   15  0.000792  4  0.000000  0.000000
# Cluster: #2, cluster chapters: [1, 2, 3]
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tf = pd.concat([tf, row_df], ignore_index=True)
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   idf = pd.concat([idf, row_df], ignore_index=True)
#             word                                          word_type   tc  \
# 0          harry  {'NNP': 190, 'PERSON': 184, 'GSP': 2, 'ORGANIZ...  195
# 1         dudley  {'NNP': 110, 'PERSON': 101, 'NN': 3, 'GPE': 8,...  116
# 2         vernon  {'NNP': 95, 'PERSON': 88, 'GPE': 4, 'ORGANIZAT...   98
# 3          uncle  {'NNP': 76, 'PERSON': 86, 'NN': 19, 'ORGANIZAT...   95
# 4   uncle vernon  {'ORGANIZATION': 6, 'PERSON': 174, 'GPE': 5, '...   90
# 6           aunt  {'NNP': 44, 'ORGANIZATION': 2, 'NN': 8, 'PERSO...   52
# 7        petunia  {'NNP': 47, 'ORGANIZATION': 2, 'PERSON': 43, '...   48
# 8   aunt petunia  {'ORGANIZATION': 4, 'PERSON': 85, 'GPE': 2, 'N...   45
# 10           one                     {'NN': 13, 'CD': 30, 'NNP': 1}   44
# 11          like                       {'IN': 40, 'JJ': 1, 'VB': 1}   42
# 13        hagrid  {'NNP': 34, 'PERSON': 24, 'GPE': 9, 'RB': 2, '...   40
# 14         could                                         {'MD': 57}   39
# 18        letter                                         {'NN': 25}   26
# 21      dursleys         {'NNP': 24, 'ORGANIZATION': 24, 'NNPS': 1}   25
# 22          time                                         {'NN': 24}   24
# 24         house                                         {'NN': 21}   21
# 27          room                               {'NN': 19, 'NNP': 1}   20
# 28          door                                         {'NN': 20}   20
# 29      cupboard            {'NN': 19, 'NNP': 1, 'ORGANIZATION': 1}   20
# 30         first         {'JJ': 16, 'NNP': 1, 'PERSON': 1, 'RB': 1}   19
# 31        school            {'NN': 16, 'NNP': 2, 'ORGANIZATION': 2}   19
# 36       letters           {'NNP': 1, 'ORGANIZATION': 1, 'NNS': 16}   17
# 37           day                                         {'NN': 17}   17
# 38           car                                {'NN': 16, 'VB': 1}   17
# 39           old                               {'JJ': 15, 'NNP': 1}   17
# 40      anything                                         {'NN': 16}   16
# 41          head                  {'NN': 15, 'NNP': 1, 'PERSON': 1}   16
# 42           way                                         {'NN': 16}   16
# 44         snake                               {'NN': 15, 'NNP': 1}   16
# 47         piers  {'NNP': 11, 'PERSON': 9, 'NNPS': 1, 'ORGANIZAT...   15
# 48        though                                         {'IN': 15}   15
# 49         giant                                {'JJ': 4, 'NN': 11}   15
# 50          hand                                         {'NN': 15}   15
# 52          face                                         {'NN': 14}   14
# 57       kitchen                                         {'NN': 14}   14
# 59      hogwarts  {'NNP': 9, 'ORGANIZATION': 6, 'PERSON': 3, 'NN...   14
# 62          eyes                                        {'NNS': 12}   13
# 63          next                                {'JJ': 12, 'IN': 1}   13
# 65        things                                        {'NNS': 13}   13
# 67           yer    {'NN': 8, 'CC': 1, 'PRP': 1, 'NNP': 2, 'JJ': 1}   13
# 69        behind                                {'IN': 12, 'NN': 1}   13
# 71        potter                          {'NNP': 13, 'PERSON': 11}   13
# 73         glass            {'NNP': 1, 'ORGANIZATION': 1, 'NN': 11}   12
# 74           boy             {'NN': 7, 'NNS': 1, 'UH': 2, 'VBD': 1}   12
# 75        wizard                   {'NN': 9, 'NNP': 1, 'PERSON': 1}   12
# 77         great  {'JJ': 9, 'NNP': 3, 'PERSON': 1, 'ORGANIZATION...   12
# 79    dumbledore  {'NNP': 9, 'PERSON': 5, 'ORGANIZATION': 2, 'GP...   11
# 80         would                                         {'MD': 19}   11
# 81         green                        {'JJ': 8, 'VB': 1, 'NN': 1}   11
# 82         large                                         {'JJ': 11}   11
#
#           tf dc       idf    tf_idf
# 0   0.017173  3  0.000000  0.000000
# 1   0.010216  3  0.000000  0.000000
# 2   0.008631  3  0.000000  0.000000
# 3   0.008366  3  0.000000  0.000000
# 4   0.007926  3  0.000000  0.000000
# 6   0.004579  3  0.000000  0.000000
# 7   0.004227  3  0.000000  0.000000
# 8   0.003963  3  0.000000  0.000000
# 10  0.003875  3  0.000000  0.000000
# 11  0.003699  3  0.000000  0.000000
# 13  0.003523  1  1.098612  0.003870
# 14  0.003435  3  0.000000  0.000000
# 18  0.002290  3  0.000000  0.000000
# 21  0.002202  3  0.000000  0.000000
# 22  0.002114  3  0.000000  0.000000
# 24  0.001849  3  0.000000  0.000000
# 27  0.001761  3  0.000000  0.000000
# 28  0.001761  3  0.000000  0.000000
# 29  0.001761  3  0.000000  0.000000
# 30  0.001673  3  0.000000  0.000000
# 31  0.001673  3  0.000000  0.000000
# 36  0.001497  2  0.405465  0.000607
# 37  0.001497  3  0.000000  0.000000
# 38  0.001497  3  0.000000  0.000000
# 39  0.001497  3  0.000000  0.000000
# 40  0.001409  3  0.000000  0.000000
# 41  0.001409  3  0.000000  0.000000
# 42  0.001409  3  0.000000  0.000000
# 44  0.001409  2  0.405465  0.000571
# 47  0.001321  2  0.405465  0.000536
# 48  0.001321  3  0.000000  0.000000
# 49  0.001321  2  0.405465  0.000536
# 50  0.001321  3  0.000000  0.000000
# 52  0.001233  3  0.000000  0.000000
# 57  0.001233  2  0.405465  0.000500
# 59  0.001233  1  1.098612  0.001355
# 62  0.001145  3  0.000000  0.000000
# 63  0.001145  3  0.000000  0.000000
# 65  0.001145  3  0.000000  0.000000
# 67  0.001145  1  1.098612  0.001258
# 69  0.001145  3  0.000000  0.000000
# 71  0.001145  3  0.000000  0.000000
# 73  0.001057  1  1.098612  0.001161
# 74  0.001057  3  0.000000  0.000000
# 75  0.001057  1  1.098612  0.001161
# 77  0.001057  3  0.000000  0.000000
# 79  0.000969  1  1.098612  0.001064
# 80  0.000969  3  0.000000  0.000000
# 81  0.000969  3  0.000000  0.000000
# 82  0.000969  3  0.000000  0.000000
# Cluster: #3, cluster chapters: [5, 6, 8, 9, 10, 11, 12, 15, 16]
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tf = pd.concat([tf, row_df], ignore_index=True)
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   idf = pd.concat([idf, row_df], ignore_index=True)
#                     word                                          word_type  \
# 0                  harry  {'NNP': 739, 'PERSON': 739, 'NN': 26, 'ORGANIZ...
# 2                    ron  {'NNP': 298, 'PERSON': 297, 'RB': 42, 'NN': 15...
# 3               hermione  {'JJ': 1, 'PERSON': 163, 'NNP': 135, 'GPE': 5,...
# 4                    one                              {'CD': 118, 'NN': 24}
# 6                  snape  {'NNP': 110, 'ORGANIZATION': 1, 'PERSON': 107,...
# 10             professor  {'NNP': 101, 'PERSON': 34, 'VB': 3, 'ORGANIZAT...
# 12                 could                 {'MD': 161, 'NNP': 1, 'PERSON': 1}
# 13            dumbledore  {'NNP': 81, 'PERSON': 55, 'RB': 9, 'GPE': 12, ...
# 14                  like                       {'IN': 86, 'VB': 9, 'JJ': 3}
# 16               neville  {'NNP': 83, 'GPE': 14, 'PERSON': 66, 'NN': 1, ...
# 18                hagrid  {'NNP': 78, 'PERSON': 66, 'GPE': 19, 'NN': 6, ...
# 20                malfoy  {'NNP': 78, 'GPE': 31, 'PERSON': 50, 'RB': 1, ...
# 21              quirrell  {'NNP': 72, 'ORGANIZATION': 33, 'PERSON': 37, ...
# 24             something                               {'NN': 74, 'VBG': 4}
# 27            gryffindor  {'NNP': 68, 'GPE': 10, 'NN': 5, 'ORGANIZATION'...
# 32                  face                                {'NN': 56, 'VB': 6}
# 33                  time                                         {'NN': 65}
# 36                  door                                         {'NN': 64}
# 37                   two            {'CD': 59, 'ORGANIZATION': 4, 'NNP': 1}
# 38                  room                                         {'NN': 61}
# 39                 three                                {'CD': 45, 'JJ': 2}
# 40                 stone       {'NN': 22, 'NNP': 36, 'PERSON': 1, 'GPE': 1}
# 41                 would                                         {'MD': 82}
# 43                  next                       {'JJ': 56, 'IN': 2, 'RB': 2}
# 45            mcgonagall  {'NNP': 56, 'PERSON': 18, 'ORGANIZATION': 15, ...
# 47                  wood  {'NNP': 38, 'PERSON': 49, 'NN': 18, 'ORGANIZAT...
# 48                  eyes                                        {'NNS': 55}
# 49                   way                               {'NN': 53, 'NNP': 1}
# 51  professor mcgonagall  {'ORGANIZATION': 27, 'PERSON': 52, 'GPE': 2, '...
# 53                  head   {'NN': 48, 'VBN': 1, 'JJ': 1, 'NNP': 1, 'VB': 1}
# 55                  good                      {'JJ': 46, 'ORGANIZATION': 1}
# 56                  last                                         {'JJ': 48}
# 59                toward                                         {'IN': 48}
# 63             quidditch  {'NNP': 41, 'GPE': 25, 'NN': 2, 'JJ': 2, 'ORGA...
# 64                 great  {'JJ': 28, 'GPE': 3, 'NNP': 18, 'PERSON': 4, '...
# 65                people                                        {'NNS': 46}
# 66                mirror            {'NNP': 6, 'ORGANIZATION': 7, 'NN': 40}
# 68                   boy                                {'UH': 5, 'NN': 39}
# 69                potter  {'NNP': 32, 'PERSON': 31, 'NN': 8, 'RB': 3, 'O...
# 70               weasley  {'NNP': 43, 'PERSON': 32, 'ORGANIZATION': 7, '...
# 71              hogwarts  {'NNS': 7, 'ORGANIZATION': 14, 'NNP': 36, 'GPE...
# 73             slytherin  {'NNP': 37, 'PERSON': 21, 'NN': 3, 'GPE': 3, '...
# 75                behind                       {'IN': 40, 'NN': 2, 'RB': 1}
# 78                    oh                                {'UH': 39, 'JJ': 1}
# 80                  feet                                        {'NNS': 40}
# 81              anything                                         {'NN': 37}
# 82                 percy  {'NNP': 34, 'PERSON': 32, 'VB': 1, 'GPE': 1, '...
# 83                 house                                         {'NN': 39}
# 84                  must                                {'MD': 39, 'RB': 1}
# 85               nothing                                         {'NN': 37}
#
#      tc        tf dc       idf    tf_idf
# 0   777  0.017062  9  0.000000  0.000000
# 2   364  0.007993  9  0.000000  0.000000
# 3   200  0.004392  9  0.000000  0.000000
# 4   145  0.003184  9  0.000000  0.000000
# 6   135  0.002964  8  0.117783  0.000349
# 10  111  0.002437  9  0.000000  0.000000
# 12  104  0.002284  9  0.000000  0.000000
# 13   99  0.002174  9  0.000000  0.000000
# 14   98  0.002152  9  0.000000  0.000000
# 16   92  0.002020  8  0.117783  0.000238
# 18   91  0.001998  8  0.117783  0.000235
# 20   88  0.001932  7  0.251314  0.000486
# 21   85  0.001867  8  0.117783  0.000220
# 24   81  0.001779  9  0.000000  0.000000
# 27   76  0.001669  9  0.000000  0.000000
# 32   67  0.001471  9  0.000000  0.000000
# 33   67  0.001471  9  0.000000  0.000000
# 36   64  0.001405  9  0.000000  0.000000
# 37   63  0.001383  8  0.117783  0.000163
# 38   62  0.001361  9  0.000000  0.000000
# 39   61  0.001340  9  0.000000  0.000000
# 40   61  0.001340  6  0.405465  0.000543
# 41   61  0.001340  9  0.000000  0.000000
# 43   60  0.001318  9  0.000000  0.000000
# 45   57  0.001252  8  0.117783  0.000147
# 47   56  0.001230  5  0.587787  0.000723
# 48   55  0.001208  9  0.000000  0.000000
# 49   54  0.001186  9  0.000000  0.000000
# 51   53  0.001164  8  0.117783  0.000137
# 53   52  0.001142  9  0.000000  0.000000
# 55   51  0.001120  9  0.000000  0.000000
# 56   50  0.001098  9  0.000000  0.000000
# 59   48  0.001054  8  0.117783  0.000124
# 63   47  0.001032  9  0.000000  0.000000
# 64   46  0.001010  8  0.117783  0.000119
# 65   46  0.001010  9  0.000000  0.000000
# 66   46  0.001010  3  1.098612  0.001110
# 68   45  0.000988  5  0.587787  0.000581
# 69   45  0.000988  8  0.117783  0.000116
# 70   45  0.000988  9  0.000000  0.000000
# 71   44  0.000966  9  0.000000  0.000000
# 73   43  0.000944  6  0.405465  0.000383
# 75   43  0.000944  9  0.000000  0.000000
# 78   41  0.000900  8  0.117783  0.000106
# 80   40  0.000878  9  0.000000  0.000000
# 81   40  0.000878  8  0.117783  0.000103
# 82   39  0.000856  6  0.405465  0.000347
# 83   39  0.000856  8  0.117783  0.000101
# 84   39  0.000856  9  0.000000  0.000000
# 85   38  0.000834  8  0.117783  0.000098
# Cluster: #4, cluster chapters: [0]
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tf = pd.concat([tf, row_df], ignore_index=True)
# /home/zhutchens/uncc/research/hierarchical_clustering/concept_hierarchies/preprocessing.py:352: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   idf = pd.concat([idf, row_df], ignore_index=True)
#                     word                                          word_type  \
# 0                dursley                          {'NNP': 47, 'PERSON': 41}
# 1             dumbledore  {'NNP': 31, 'PERSON': 23, 'ORGANIZATION': 2, '...
# 4              professor  {'NNP': 29, 'PERSON': 17, 'ORGANIZATION': 1, '...
# 6             mcgonagall       {'NNP': 25, 'PERSON': 15, 'ORGANIZATION': 2}
# 7   professor mcgonagall  {'ORGANIZATION': 3, 'NNP': 54, 'VB': 1, 'PERSO...
# 8                    cat                                {'NN': 20, 'JJ': 1}
# 10                people                                        {'NNS': 21}
# 11                 harry                          {'NNP': 20, 'PERSON': 20}
# 15                 could                                         {'MD': 27}
# 16             something                                         {'NN': 14}
# 17                street                                         {'NN': 14}
# 18                hagrid  {'PRP': 1, 'NNP': 12, 'PERSON': 9, 'JJ': 1, 'G...
# 20                  name                                         {'NN': 11}
# 21                  owls              {'JJ': 3, 'NN': 6, 'NNP': 1, 'RB': 1}
# 22                potter        {'NNP': 10, 'PERSON': 8, 'ORGANIZATION': 1}
# 23                   yes                                         {'UH': 11}
# 25                 would                                         {'MD': 15}
# 26                   man                                         {'NN': 10}
# 29                  eyes                                        {'NNS': 10}
# 30                   boy    {'NNP': 1, 'ORGANIZATION': 1, 'RB': 1, 'NN': 8}
# 32               potters  {'NNP': 1, 'ORGANIZATION': 9, 'NNPS': 6, 'NNS'...
# 33                   day                                          {'NN': 9}
# 34                  like                                          {'IN': 9}
# 35                 cloak                                          {'NN': 9}
# 38                little                                          {'JJ': 9}
# 39                 drive  {'NNP': 8, 'PERSON': 3, 'NN': 1, 'ORGANIZATION...
# 41                dudley                            {'NNP': 9, 'PERSON': 9}
# 43                  last                                          {'JJ': 8}
# 44                privet         {'NNP': 8, 'PERSON': 3, 'ORGANIZATION': 5}
# 45          privet drive  {'ORGANIZATION': 10, 'NNP': 16, 'NN': 1, 'PERS...
# 49                  next                                {'JJ': 7, 'NNP': 1}
# 50                  good                                          {'JJ': 4}
# 52                corner                                          {'NN': 7}
# 54                  wall                                          {'NN': 7}
# 55                number                                          {'NN': 7}
# 59                   son                                          {'NN': 7}
# 60              dursleys                      {'NNP': 7, 'ORGANIZATION': 7}
# 61                sister                                          {'NN': 7}
# 64           number four                                 {'CD': 6, 'NN': 7}
# 65             voldemort                   {'NNP': 4, 'PERSON': 5, 'NN': 1}
# 66                drills                                         {'NNS': 6}
# 67                  four                                          {'CD': 6}
# 68                  mind                                          {'NN': 6}
# 73                reason                                          {'NN': 6}
# 74               muggles  {'NNP': 5, 'PERSON': 4, 'NNS': 1, 'ORGANIZATIO...
# 78                   two                                          {'CD': 6}
# 83                   one                                 {'CD': 5, 'NN': 1}
# 84                 night                   {'NN': 4, 'NNP': 1, 'PERSON': 1}
# 85                  sign                                          {'NN': 5}
# 86                  half                                 {'JJ': 1, 'NN': 2}
#
#     tc        tf dc  idf  tf_idf
# 0   47  0.009837  1  0.0     0.0
# 1   37  0.007744  1  0.0     0.0
# 4   30  0.006279  1  0.0     0.0
# 6   26  0.005442  1  0.0     0.0
# 7   26  0.005442  1  0.0     0.0
# 8   21  0.004395  1  0.0     0.0
# 10  21  0.004395  1  0.0     0.0
# 11  20  0.004186  1  0.0     0.0
# 15  14  0.002930  1  0.0     0.0
# 16  14  0.002930  1  0.0     0.0
# 17  14  0.002930  1  0.0     0.0
# 18  14  0.002930  1  0.0     0.0
# 20  11  0.002302  1  0.0     0.0
# 21  11  0.002302  1  0.0     0.0
# 22  11  0.002302  1  0.0     0.0
# 23  11  0.002302  1  0.0     0.0
# 25  11  0.002302  1  0.0     0.0
# 26  10  0.002093  1  0.0     0.0
# 29  10  0.002093  1  0.0     0.0
# 30  10  0.002093  1  0.0     0.0
# 32  10  0.002093  1  0.0     0.0
# 33   9  0.001884  1  0.0     0.0
# 34   9  0.001884  1  0.0     0.0
# 35   9  0.001884  1  0.0     0.0
# 38   9  0.001884  1  0.0     0.0
# 39   9  0.001884  1  0.0     0.0
# 41   9  0.001884  1  0.0     0.0
# 43   8  0.001674  1  0.0     0.0
# 44   8  0.001674  1  0.0     0.0
# 45   8  0.001674  1  0.0     0.0
# 49   8  0.001674  1  0.0     0.0
# 50   7  0.001465  1  0.0     0.0
# 52   7  0.001465  1  0.0     0.0
# 54   7  0.001465  1  0.0     0.0
# 55   7  0.001465  1  0.0     0.0
# 59   7  0.001465  1  0.0     0.0
# 60   7  0.001465  1  0.0     0.0
# 61   7  0.001465  1  0.0     0.0
# 64   6  0.001256  1  0.0     0.0
# 65   6  0.001256  1  0.0     0.0
# 66   6  0.001256  1  0.0     0.0
# 67   6  0.001256  1  0.0     0.0
# 68   6  0.001256  1  0.0     0.0
# 73   6  0.001256  1  0.0     0.0
# 74   6  0.001256  1  0.0     0.0
# 78   6  0.001256  1  0.0     0.0
# 83   6  0.001256  1  0.0     0.0
# 84   6  0.001256  1  0.0     0.0
# 85   5  0.001046  1  0.0     0.0
# 86   5  0.001046  1  0.0     0.0
